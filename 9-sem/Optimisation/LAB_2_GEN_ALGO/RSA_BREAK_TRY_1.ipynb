# %% [markdown]
# Goal: Use a simple genetic algorithm (as in Holland’s and Goldberg’s “simple GA”) to approximate the unknown plaintext a such that
# rsa_lib.encrypt_text(candidate, public_key, n) is as close as possible (in mean squared error) to the given ciphertext b.

# %%
import random
from pathlib import Path

# Import your RSA library
from var import rsa_lib

# %%
# Directly from 8_encrypted_text.txt (variant 8)
ciphertext = [
    4012, 216, 1403, 10437, 8192, 15617, 1403, 8192, 216, 17270, 696, 1403,
    8192, 12593, 216, 19224, 18807, 18807, 15951, 1403, 13821, 8192, 11101,
    18807, 18807, 8192, 20733, 216, 7555, 12593, 8192, 31197, 11101, 692,
    20733, 17270, 15951, 8192, 30299, 11101, 7555, 15951
]

public_key = 65537
n = 33227

len(ciphertext), public_key, n
# Out:
# (42, 65537, 33227)

# %%
ALPHABET = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ, "
ALPHABET_SIZE = len(ALPHABET)
TEXT_LENGTH = 42  # must match the length of the unknown plaintext

# %%
def random_char():
    return random.choice(ALPHABET)

def random_text(length=TEXT_LENGTH):
    return "".join(random_char() for _ in range(length))

# %%
def encrypt_candidate(text):
    """
    Encrypt candidate plaintext using the given rsa_lib.
    Returns a list (or iterable) of integers.
    """
    return rsa_lib.encrypt_text(text, public_key, n)

# %% [markdown]
# Define the error \( P \) and fitness:
#
# $$
# P(x, b) = \frac{1}{n} \sum_{i=1}^n (b'_i - b_i)^2
# $$
#
# and convert this to a fitness to maximize, e.g.:
#
# $$
# \text{F}(x) = \frac{1}{1 + P(x, b)}
# $$

# %%
def error_P(candidate_text, target_cipher):
    cand_cipher = encrypt_candidate(candidate_text)

    # Safety: use min length if for some reason they differ
    L = min(len(cand_cipher), len(target_cipher))
    s = 0.0
    for i in range(L):
        diff = cand_cipher[i] - target_cipher[i]
        s += diff * diff
    return s / L

def fitness(candidate_text, target_cipher):
    P = error_P(candidate_text, target_cipher)
    return 1.0 / (1.0 + P)  # smaller error -> larger fitness

# %% [markdown]
# Initialize the population

# %%
POP_SIZE = 100

def initialize_population():
    return [random_text(TEXT_LENGTH) for _ in range(POP_SIZE)]

population = initialize_population()
len(population), population[0][:10]
# Out:
# (100, 'ABpElADmfj')

# %% [markdown]
# Selection operator (tournament selection)

# %%
def tournament_select(population, fitnesses, tournament_size=3):
    """
    Return one selected individual from population using tournament selection.
    """
    selected_idx = random.randrange(len(population))
    for _ in range(tournament_size - 1):
        i = random.randrange(len(population))
        if fitnesses[i] > fitnesses[selected_idx]:
            selected_idx = i
    return population[selected_idx]

# %% [markdown]
# Crossover operator (one-point crossover on strings)

# %%
def one_point_crossover(parent1, parent2):
    assert len(parent1) == len(parent2)
    L = len(parent1)
    if L < 2:
        return parent1, parent2
    cut = random.randint(1, L - 1)  # cut point between 1 and L-1
    child1 = parent1[:cut] + parent2[cut:]
    child2 = parent2[:cut] + parent1[cut:]
    return child1, child2

# %% [markdown]
# Mutation operator ( with small probability per position, change a character to a random other character from the alphabet)

# %%
MUTATION_RATE = 0.02  # probability of mutating each character

def mutate(text):
    text_list = list(text)
    for i in range(len(text_list)):
        if random.random() < MUTATION_RATE:
            text_list[i] = random_char()
    return "".join(text_list)

# %% [markdown]
# One GA generation (with elitism)

# %%
CROSSOVER_RATE = 0.8
ELITE_COUNT = 2  # number of best individuals preserved each generation

# %%
def make_next_generation(population, target_cipher):
    # 1. Evaluate current population
    fitnesses = [fitness(ind, target_cipher) for ind in population]

    # 2. Sort by fitness (descending)
    pop_fit = list(zip(population, fitnesses))
    pop_fit.sort(key=lambda x: x[1], reverse=True)

    # 3. Elites
    new_population = [ind for ind, fit in pop_fit[:ELITE_COUNT]]

    # 4. Generate the rest via selection, crossover, mutation
    while len(new_population) < POP_SIZE:
        # Parent selection
        parent1 = tournament_select(population, fitnesses)
        parent2 = tournament_select(population, fitnesses)

        # Crossover
        if random.random() < CROSSOVER_RATE:
            child1, child2 = one_point_crossover(parent1, parent2)
        else:
            child1, child2 = parent1, parent2

        # Mutation
        child1 = mutate(child1)
        child2 = mutate(child2)

        new_population.append(child1)
        if len(new_population) < POP_SIZE:
            new_population.append(child2)

    # Also return current best individual for logging
    best_ind, best_fit = pop_fit[0]
    return new_population, best_ind, best_fit

# %%
MAX_GENERATIONS = 20000  # you can adjust
TARGET_ERROR_THRESHOLD = 0.0  # stop if exact match is found

population = initialize_population()

for generation in range(MAX_GENERATIONS):
    # Evaluate and evolve
    population, best_ind, best_fit = make_next_generation(population, ciphertext)

    # Compute error explicitly for reporting
    best_error = error_P(best_ind, ciphertext)

    # REQUIRED OUTPUT: best current result for this iteration
    print(f"Generation {generation:4d} | best error P = {best_error:.6f} | best text = {repr(best_ind)}")

    # Stop if we hit perfect match (P = 0)
    if best_error <= TARGET_ERROR_THRESHOLD:
        print("Exact match found, stopping.")
        break
# Out:
# Generation    0 | best error P = 105282051.523810 | best text = 'lHOAxFpwilPRoizOViLulFrUtR,R  y,aVADGyqVtP'
# Generation    1 | best error P = 100236704.761905 | best text = 'ayNQAiyXoUbBZEEXDwsDQZGCqeuRiBuwTp stMYrRb'
# Generation    2 | best error P = 83871063.595238 | best text = 'EWxotJddiDRsfNLQBWoxquZMYbQPOAiSJPLXNpuPJl'
# Generation    3 | best error P = 81607290.666667 | best text = 'EWxodJdyiDRsfNLQBiLulFrUtR,R  y,aVADGMYrRb'
# Generation    4 | best error P = 67965887.095238 | best text = 'EWxodJpwilPRoiHpIwiDSIchlhMIRJRCJPLXNpuPJl'
# Generation    5 | best error P = 62409164.000000 | best text = 'EFxodJdydsDqdTAbTHyRfFrUtR,R  y,aVADGMYrRb'
# Generation    6 | best error P = 59910404.333333 | best text = 'EWxotJdd lPqdTJbTHyRfFrUtR,R  y,aEADGMJrRb'
# Generation    7 | best error P = 51228942.642857 | best text = 'EWxotJdd lPqdTJbTHyRfFrUlR,R  y,aEAQtxOGJl'
# Generation    8 | best error P = 49241427.142857 | best text = 'EWxodJpwilPRoiHpIwyRfguQAhxUDsZSUqNzulCPJD'
# Generation    9 | best error P = 45445912.690476 | best text = 'EWxodJpwisDqdT bTHyRfFrUlR,R  y,aEAJtxOGJl'
# Generation   10 | best error P = 42876713.047619 | best text = 'EWxodJpwisDqdT bTHyRfFnUlR,R  y,aEAJtxOGJl'
# Generation   11 | best error P = 39270320.833333 | best text = 'EWxodJdpesDqdTJbTHORfFrUtR,R  y,aqNzulCPJD'
# Generation   12 | best error P = 32371507.261905 | best text = 'EWxodJepesDqdTJbNHuRfFrUtR,R  y,aEZfulCPJD'
# Generation   13 | best error P = 32371507.261905 | best text = 'EWxodJepesDqdTJbNHuRfFrUtR,R  y,aEZfulCPJD'
# Generation   14 | best error P = 32371507.261905 | best text = 'EWxodJepesDqdTJbNHuRfFrUtR,R  y,aEZfulCPJD'
# Generation   15 | best error P = 32371507.261905 | best text = 'EWxodJepesDqdTJbNHuRfFrUtR,R  y,aEZfulCPJD'
# Generation   16 | best error P = 28965668.309524 | best text = 'EWxodJepesDqdTJATXORfFrUtR,R  y,aEZfulCPJD'
# Generation   17 | best error P = 27082007.928571 | best text = 'EWxodJepesDqdTJbNMuRfFrUtRdR  y,aEZfulCPJD'
# Generation   18 | best error P = 25157672.309524 | best text = 'EWooZJepesDqdT oIxyRfFJUtRlR  yLaEZfulCPJD'
# Generation   19 | best error P = 23164277.785714 | best text = 'EWxodJepesDqdTJbNMuRfFJUtRlr  y,PEZfnlCPJD'
# Generation   20 | best error P = 23164277.785714 | best text = 'EWxodJepesDqdTJbNMuRfFJUtRlr  y,PEZfnlCPJD'
# Generation   21 | best error P = 20007525.000000 | best text = 'EWooZJepesDqdTJATXORfFJGtRlr  y,aEZfuFCPJD'
# Generation   22 | best error P = 20007525.000000 | best text = 'EWooZJepesDqdTJATXORfFJGtRlr  y,aEZfuFCPJD'
# Generation   23 | best error P = 19121857.023810 | best text = 'EWoodJeZesRqoi oTXORfFJGtRlr  y,aEZfuFCPJD'
# Generation   24 | best error P = 18917014.738095 | best text = 'EWooZJepesWqdTJbNMURfFJUtRlr  y,aEZfMlCPJd'
# Generation   25 | best error P = 17703984.238095 | best text = 'EWEoZJephsDqdTJTTdtRfFJGtRlr py,pEBfuFCPJD'
# Generation   26 | best error P = 16331870.357143 | best text = 'EWEoDJeZesRqoi oxxuRfFJUtRlr  y,PEZfnlCPJw'
# Generation   27 | best error P = 15800274.500000 | best text = 'EWEoZJepesDqdTJAuXORfFJGtRlr py,pEBfuFCPJD'
# Generation   28 | best error P = 15474027.500000 | best text = 'EWEoDJeZesRqoi gxxuRfFJUtRlr  y,PEZfnlCPJw'
# Generation   29 | best error P = 15235993.285714 | best text = 'EW oZTepesRqsT ATXORAFJGtRlr  y,aEZZuFCPJD'
# Generation   30 | best error P = 14761127.214286 | best text = 'EWEoDQeZesRqoi oxxuRfFJUtRlr  y,PEZfuFCPJf'
# Generation   31 | best error P = 13190420.238095 | best text = 'EWEoZJepesRqsT ATXORAFJGtRlr  y,aEwfuFCPJf'
# Generation   32 | best error P = 11889457.452381 | best text = 'EWEoZJepesRqsT ATXORAFJGtRlr oy,pEBfuFCPJf'
# Generation   33 | best error P = 11889457.452381 | best text = 'EWEoZJepesRqsT ATXORAFJGtRlr oy,pEBfuFCPJf'
# Generation   34 | best error P = 11832013.071429 | best text = 'EWRodJeZesRqoT ATXORAFJGtRlr oy,pEBfuFCPJf'
# Generation   35 | best error P = 11286062.595238 | best text = 'EWRodJeZesRqoT ATXORAFJGtRlr oy,pEIfuFCPJf'
# Generation   36 | best error P = 10455469.595238 | best text = 'EWRodJeHesRqoT ATXORAnJGtRlr oy,pEIfuFCPJf'
# Generation   37 | best error P = 10455469.595238 | best text = 'EWRodJeHesRqoT ATXORAnJGtRlr oy,pEIfuFCPJf'
# Generation   38 | best error P = 10455469.595238 | best text = 'EWRodJeHesRqoT ATXORAnJGtRlr oy,pEIfuFCPJf'
# Generation   39 | best error P = 10455469.595238 | best text = 'EWRodJeHesRqoT ATXORAnJGtRlr oy,pEIfuFCPJf'
# Generation   40 | best error P = 10455469.595238 | best text = 'EWRodJeHesRqoT ATXORAnJGtRlr oy,pEIfuFCPJf'
# Generation   41 | best error P = 10117927.095238 | best text = 'EWRodJepeARqsT fTXORAFJGtRlr oy,pEIfuFCPJf'
# Generation   42 | best error P = 9765887.690476 | best text = 'EWRodJepesRqoT ATXORADJGtRlr oo,pEIfuFCPJf'
# Generation   43 | best error P = 9641734.214286 | best text = 'EWRodJeHesRqoTrATXORAnMGtRlr oy,pEIfuFCPsf'
# Generation   44 | best error P = 8995104.261905 | best text = 'EWRodJeHesRqoT AuXORUDJGtRlr oo,pEIfuFCPJf'
# Generation   45 | best error P = 8722366.000000 | best text = 'HWRodJeHeVRqoT ATXORADJGtRtr oo,pEIfuoCPJf'
# Generation   46 | best error P = 7954772.142857 | best text = 'ErRoRJrHesRqoTrATXORADJGtRlr oyzpEIfuFCPJO'
# Generation   47 | best error P = 7954772.142857 | best text = 'ErRoRJrHesRqoTrATXORADJGtRlr oyzpEIfuFCPJO'
# Generation   48 | best error P = 7903734.190476 | best text = 'EWRodJeHesRqoTrATXORAnJGtRlr oi,pEIfuFCPJO'
# Generation   49 | best error P = 7903734.190476 | best text = 'EWRodJeHesRqoTrATXORAnJGtRlr oi,pEIfuFCPJO'
# Generation   50 | best error P = 7450905.595238 | best text = 'EWRodJeHesRqoThATXORAnJGt lr oi,pEIfuFCPJO'
# Generation   51 | best error P = 7161350.380952 | best text = 'EWRoRJrHesRqoTrATXORAnJGt lr oi,pEIfuFCPJO'
# Generation   52 | best error P = 6798127.047619 | best text = 'ErRoRJrHesRqoTrATXORADJGtRtr oo,pEIfdoCPJf'
# Generation   53 | best error P = 6745607.238095 | best text = 'EWRiEJeHesRqoTrAuXORADZGtRlr oxzprIfuFCPJO'
# Generation   54 | best error P = 6505912.595238 | best text = 'ErRoRQrHesRqoTrATXORADJGtRtr oo,pEIfdoCPJO'
# Generation   55 | best error P = 6505912.595238 | best text = 'ErRoRQrHesRqoTrATXORADJGtRtr oo,pEIfdoCPJO'
# Generation   56 | best error P = 6170440.666667 | best text = 'EWRiEJeHesRqoTrAuXORADJGtRtr oo,pEIfdoCPJf'
# Generation   57 | best error P = 5986385.666667 | best text = 'ErRoRVeHeaRqoTrATXOvAnJGtRtr oo,pEIfdoCPJf'
# Generation   58 | best error P = 5986076.690476 | best text = 'EWRiEJeHesRqoTrAuXORADJGtRtr oo,pEIfdoCPJO'
# Generation   59 | best error P = 5572465.928571 | best text = 'ErRoEJeHesRqoTrAuXORAnJGtRtr oo,pEIfdoCPJO'
# Generation   60 | best error P = 5461122.690476 | best text = 'ErRoEJeHesRqoTrAuXORADJGtRtr oo,pEIfdoCPJO'
# Generation   61 | best error P = 5405815.142857 | best text = 'ErRoNJrHesRqoTrAuXORADJGtRtr oo,phIfdoCPJO'
# Generation   62 | best error P = 5022017.714286 | best text = 'ErRoEMeHesRqoTrAuXORADJGtRtr oi,pEIfuFCPJO'
# Generation   63 | best error P = 5022017.714286 | best text = 'ErRoEMeHesRqoTrAuXORADJGtRtr oi,pEIfuFCPJO'
# Generation   64 | best error P = 4771217.976190 | best text = 'ErRoRVeHeaRqoTrAuIORADJGtRtr oi,THIfdoCPJO'
# Generation   65 | best error P = 4268421.523810 | best text = 'ErRoEMrHesRqoTrAuXORADJGtRtr oo,phIfdoCPJO'
# Generation   66 | best error P = 4268421.523810 | best text = 'ErRoEMrHesRqoTrAuXORADJGtRtr oo,phIfdoCPJO'
# Generation   67 | best error P = 4060444.428571 | best text = 'ErRoRVeHeaeqoTrAuXORADJGtRtr oo,phIfdoCPJO'
# Generation   68 | best error P = 3840210.166667 | best text = 'EWRiEOeHeaRqoTrAuIORADJGtRtr oo,phIfdoCPJO'
# Generation   69 | best error P = 3815213.309524 | best text = 'ErRoEMeHesRqoTrAuIORADJGtRtr oo,phIfdoCPJO'
# Generation   70 | best error P = 3437394.238095 | best text = 'ErRoRMeHeaeqoTrAuIORADJGtRtr oo,phIfdoCPJO'
# Generation   71 | best error P = 3315256.166667 | best text = 'ErRoEOeHeaRqoTrAuIORADJGtRtr oo,phIfdoCPJO'
# Generation   72 | best error P = 3315256.166667 | best text = 'ErRoEOeHeaRqoTrAuIORADJGtRtr oo,phIfdoCPJO'
# Generation   73 | best error P = 3302638.380952 | best text = 'ErRoEOeHeaRqoTrAuIORADJGtRtr oo,FhIfdoCPJO'
# Generation   74 | best error P = 3186790.047619 | best text = 'ErRoEOeHeaeqoTrAuZMRADJGVDtr oo,phIfdoCPJO'
# Generation   75 | best error P = 2871661.880952 | best text = 'ErRoEMeDesRqoTrIuIORADJGVDtr oo,phIfdoCPJO'
# Generation   76 | best error P = 2486097.476190 | best text = 'ErRoEOeHeaRvFTrAuIORADJGVDtr oo,phIfdoCPHO'
# Generation   77 | best error P = 2486097.476190 | best text = 'ErRoEOeHeaRvFTrAuIORADJGVDtr oo,phIfdoCPHO'
# Generation   78 | best error P = 2486097.476190 | best text = 'ErRoEOeHeaRvFTrAuIORADJGVDtr oo,phIfdoCPHO'
# Generation   79 | best error P = 2486097.476190 | best text = 'ErRoEOeHeaRvFTrAuIORADJGVDtr oo,phIfdoCPHO'
# Generation   80 | best error P = 2486097.476190 | best text = 'ErRoEOeHeaRvFTrAuIORADJGVDtr oo,phIfdoCPHO'
# Generation   81 | best error P = 2277057.357143 | best text = 'ErRoEOeHeaeqoTrAuIMRADJGVDtr po,phIVdoCPHO'
# Generation   82 | best error P = 1831765.857143 | best text = 'ErRoEOeHeaeqoTrIuIORAHJGVDtr oo,phIfdoCPHO'
# Generation   83 | best error P = 1831765.857143 | best text = 'ErRoEOeHeaeqoTrIuIORAHJGVDtr oo,phIfdoCPHO'
# Generation   84 | best error P = 1831765.857143 | best text = 'ErRoEOeHeaeqoTrIuIORAHJGVDtr oo,phIfdoCPHO'
# Generation   85 | best error P = 1831765.857143 | best text = 'ErRoEOeHeaeqoTrIuIORAHJGVDtr oo,phIfdoCPHO'
# Generation   86 | best error P = 1800215.047619 | best text = 'ErRoEMeHeaeqoTrIuIMRADJGVDtr oo,phIfdoCPHO'
# Generation   87 | best error P = 1800215.047619 | best text = 'ErRoEMeHeaeqoTrIuIMRADJGVDtr oo,phIfdoCPHO'
# Generation   88 | best error P = 1779875.357143 | best text = 'ErRoEMeHeaeqoTrIuIORAHJGVDtr oo,phQfdoCPHO'
# Generation   89 | best error P = 1749302.595238 | best text = 'ErRoEMeHeaeqoTrIuIORAHJGVDtr oompvIfdomPHO'
# Generation   90 | best error P = 1608393.333333 | best text = 'ErRoEMeHeaeqoTrIuIMRADJGVDtr oi,phIfdoCPHO'
# Generation   91 | best error P = 1608393.333333 | best text = 'ErRoEMeHeaeqoTrIuIMRADJGVDtr oi,phIfdoCPHO'
# Generation   92 | best error P = 1475793.333333 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phIfdoCPHO'
# Generation   93 | best error P = 1475793.333333 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phIfdoCPHO'
# Generation   94 | best error P = 1475793.333333 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phIfdoCPHO'
# Generation   95 | best error P = 1444763.047619 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phQfdoCPHO'
# Generation   96 | best error P = 1444763.047619 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phQfdoCPHO'
# Generation   97 | best error P = 1444763.047619 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phQfdoCPHO'
# Generation   98 | best error P = 1444763.047619 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr oi,phQfdoCPHO'
# Generation   99 | best error P = 1428312.023810 | best text = 'RrRoEMeHeaeqoTrIuIMRADJGVDtr Pi,phQfdoCPHO'
# Generation  100 | best error P = 1345182.976190 | best text = 'RrRoEMeHeaeqoTrIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  101 | best error P = 1327921.261905 | best text = 'RrRoEMeHeaeyoTrIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  102 | best error P = 1263791.738095 | best text = 'RrRoEMeHeaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  103 | best error P = 1263791.738095 | best text = 'RrRoEMeHeaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  104 | best error P = 1254603.809524 | best text = 'RrRoEMeHeaeqnTvIuIURADJGVDtr oi,phIVwoCPHO'
# Generation  105 | best error P = 1254603.809524 | best text = 'RrRoEMeHeaeqnTvIuIURADJGVDtr oi,phIVwoCPHO'
# Generation  106 | best error P = 1254603.809524 | best text = 'RrRoEMeHeaeqnTvIuIURADJGVDtr oi,phIVwoCPHO'
# Generation  107 | best error P = 1235730.571429 | best text = 'RrRoEMeHvaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  108 | best error P = 1235730.571429 | best text = 'RrRoEMeHvaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  109 | best error P = 1235730.571429 | best text = 'RrRoEMeHvaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  110 | best error P = 1235730.571429 | best text = 'RrRoEMeHvaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  111 | best error P = 1209642.023810 | best text = 'RrRnEMeHeaeynTvIuIORADJaVDtr oi,phIVwoCPHO'
# Generation  112 | best error P = 1209642.023810 | best text = 'RrRnEMeHeaeynTvIuIORADJaVDtr oi,phIVwoCPHO'
# Generation  113 | best error P = 1209642.023810 | best text = 'RrRnEMeHeaeynTvIuIORADJaVDtr oi,phIVwoCPHO'
# Generation  114 | best error P = 1157296.642857 | best text = 'RrRo MeHvaeqnTvIuIORADJGVDtr oi,phIVwoCPHO'
# Generation  115 | best error P = 1129360.500000 | best text = 'RrRnEMeHeaeynTvIuIORADJfVDtr Zi,phIVwoCPHO'
# Generation  116 | best error P = 1129360.500000 | best text = 'RrRnEMeHeaeynTvIuIORADJfVDtr Zi,phIVwoCPHO'
# Generation  117 | best error P = 1033411.333333 | best text = 'RrRnEMeHvaeqnTvIuIORADJGVDtr oi,phIVwiCPHO'
# Generation  118 | best error P = 1033411.333333 | best text = 'RrRnEMeHvaeqnTvIuIORADJGVDtr oi,phIVwiCPHO'
# Generation  119 | best error P = 1033411.333333 | best text = 'RrRnEMeHvaeqnTvIuIORADJGVDtr oi,phIVwiCPHO'
# Generation  120 | best error P = 1013786.738095 | best text = 'RrRo MeHvaeqnTvIuIORADJfVDtr oiSphIVwoCPHO'
# Generation  121 | best error P = 904602.380952 | best text = 'RrRo MeHvaeqnTvIuIORADJGVDtr oiSphIVwiCPHO'
# Generation  122 | best error P = 882837.571429 | best text = 'RrRo MeHvaeqnTvIuIORADJfVDtr oi,phIVwiCPHO'
# Generation  123 | best error P = 821965.023810 | best text = 'RrRo MeHvaeqnTvIuIORADJfVDtr oiSphIVwiCPHO'
# Generation  124 | best error P = 698157.500000 | best text = 'RrRo MeHvaeynTvIuIOeADJfVDtr Zi,phIVwiCPHO'
# Generation  125 | best error P = 698157.500000 | best text = 'RrRo MeHvaeynTvIuIOeADJfVDtr Zi,phIVwiCPHO'
# Generation  126 | best error P = 698157.500000 | best text = 'RrRo MeHvaeynTvIuIOeADJfVDtr Zi,phIVwiCPHO'
# Generation  127 | best error P = 678581.309524 | best text = 'RrRo MeHvaeqnTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  128 | best error P = 580702.452381 | best text = 'RrRo MqHvaeyDTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  129 | best error P = 580702.452381 | best text = 'RrRo MqHvaeyDTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  130 | best error P = 578835.785714 | best text = 'RrRo wqHvaeyDTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  131 | best error P = 566674.952381 | best text = 'Rrvo MeHvaeynTvIuIOeADJfVDtr Zi,phIVwiCPHO'
# Generation  132 | best error P = 549976.357143 | best text = 'RrRo MeHvaeyDTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  133 | best error P = 529837.047619 | best text = 'Rrvo MeHvaeynTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  134 | best error P = 418493.809524 | best text = 'Rrvo MeHvaeyDTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  135 | best error P = 418493.809524 | best text = 'Rrvo MeHvaeyDTvIuIOeADJfVDtr oiSphIVwiCPHO'
# Generation  136 | best error P = 372122.357143 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  137 | best error P = 372122.357143 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  138 | best error P = 372122.357143 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  139 | best error P = 372122.357143 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  140 | best error P = 372122.357143 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  141 | best error P = 372122.357143 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  142 | best error P = 366636.642857 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  143 | best error P = 366636.642857 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  144 | best error P = 366636.642857 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  145 | best error P = 365219.119048 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphIVwiCPil'
# Generation  146 | best error P = 353642.333333 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphIVwiCPHl'
# Generation  147 | best error P = 291113.761905 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  148 | best error P = 291113.761905 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  149 | best error P = 291113.761905 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  150 | best error P = 291113.761905 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  151 | best error P = 291113.761905 | best text = 'Rrvo MeHvaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  152 | best error P = 282477.761905 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr oiSphtVwiCPHO'
# Generation  153 | best error P = 278119.452381 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  154 | best error P = 278119.452381 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  155 | best error P = 278119.452381 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  156 | best error P = 278119.452381 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  157 | best error P = 278119.452381 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  158 | best error P = 278119.452381 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  159 | best error P = 272633.738095 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  160 | best error P = 272633.738095 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr oiSphtVwiCPHl'
# Generation  161 | best error P = 249694.047619 | best text = 'Rrvo MeHvaeyDTvIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  162 | best error P = 231214.023810 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  163 | best error P = 231214.023810 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  164 | best error P = 231214.023810 | best text = 'Rrvo Me vaeyDTvIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  165 | best error P = 225728.309524 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  166 | best error P = 220716.500000 | best text = 'Rrvn Me vaeyDTvIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  167 | best error P = 220716.500000 | best text = 'Rrvn Me vaeyDTvIuIOeNDJfVDtr TiSphtVwiCPHl'
# Generation  168 | best error P = 219797.928571 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSnhtVwiCPil'
# Generation  169 | best error P = 219797.928571 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSnhtVwiCPil'
# Generation  170 | best error P = 219797.928571 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSnhtVwiCPil'
# Generation  171 | best error P = 219797.928571 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSnhtVwiCPil'
# Generation  172 | best error P = 216203.642857 | best text = 'Rrvn Me vaeyDTvIuIOeNDJfVDtr TiSnhtVwiCPHl'
# Generation  173 | best error P = 214786.119048 | best text = 'Rrvn Me vaeyDTvIuIOeNDJfVDtr TiSnhtVwiCPil'
# Generation  174 | best error P = 195594.380952 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  175 | best error P = 195594.380952 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  176 | best error P = 195594.380952 | best text = 'Rrvo Me vaeyDThIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  177 | best error P = 190582.571429 | best text = 'Rrvn Me vaeyDTvIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  178 | best error P = 185096.857143 | best text = 'Rrvn Me vaeyDThIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  179 | best error P = 180712.476190 | best text = 'Rrvo Me vaeeDThIuIOeNDJfVDtr TiSphtawiCPil'
# Generation  180 | best error P = 180712.476190 | best text = 'Rrvo Me vaeeDThIuIOeNDJfVDtr TiSphtawiCPil'
# Generation  181 | best error P = 176644.285714 | best text = 'Rrvo Me haeeDThIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  182 | best error P = 166146.761905 | best text = 'Rrvn Me haeeDThIuIOeNDJfVDtr TiSphtawiCPHl'
# Generation  183 | best error P = 163205.214286 | best text = 'Rrvn Me haeeDThIuIOeNDJfVDtr TiSphtawiCoil'
# Generation  184 | best error P = 163205.214286 | best text = 'Rrvn Me haeeDThIuIOeNDJfVDtr TiSphtawiCoil'
# Generation  185 | best error P = 163205.214286 | best text = 'Rrvn Me haeeDThIuIOeNDJfVDtr TiSphtawiCoil'
# Generation  186 | best error P = 163205.214286 | best text = 'Rrvn Me haeeDThIuIOeNDJfVDtr TiSphtawiCoil'
# Generation  187 | best error P = 162507.142857 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSphtawiCPHl'
# Generation  188 | best error P = 149020.785714 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCPHl'
# Generation  189 | best error P = 149020.785714 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCPHl'
# Generation  190 | best error P = 149020.785714 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCPHl'
# Generation  191 | best error P = 149020.785714 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCPHl'
# Generation  192 | best error P = 149020.785714 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCPHl'
# Generation  193 | best error P = 147603.261905 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCPil'
# Generation  194 | best error P = 146079.238095 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCoil'
# Generation  195 | best error P = 146079.238095 | best text = 'Rrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCoil'
# Generation  196 | best error P = 145507.214286 | best text = 'Wrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCoil'
# Generation  197 | best error P = 145507.214286 | best text = 'Wrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCoil'
# Generation  198 | best error P = 145507.214286 | best text = 'Wrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCoil'
# Generation  199 | best error P = 145507.214286 | best text = 'Wrvn Me haeeDThIIIOeNDJfVDtr TiSPhtawiCoil'
# Generation  200 | best error P = 138435.809524 | best text = 'Wrvn Me haeeDTqIIIOeN JfVDtr TiSPhtawiCPil'
# Generation  201 | best error P = 138435.809524 | best text = 'Wrvn Me haeeDTqIIIOeN JfVDtr TiSPhtawiCPil'
# Generation  202 | best error P = 136911.785714 | best text = 'Wrvn Me haeeDTqIIIOeN JfVDtr TiSPhtawiCoil'
# Generation  203 | best error P = 136911.785714 | best text = 'Wrvn Me haeeDTqIIIOeN JfVDtr TiSPhtawiCoil'
# Generation  204 | best error P = 136849.857143 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtr TiSPhtawiCoil'
# Generation  205 | best error P = 136849.857143 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtr TiSPhtawiCoil'
# Generation  206 | best error P = 136849.857143 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtr TiSPhtawiCoil'
# Generation  207 | best error P = 128606.214286 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSPhtawiCoHl'
# Generation  208 | best error P = 128606.214286 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSPhtawiCoHl'
# Generation  209 | best error P = 128606.214286 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSPhtawiCoHl'
# Generation  210 | best error P = 127188.690476 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSPhtawiCoil'
# Generation  211 | best error P = 127082.190476 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSohtawiCoHl'
# Generation  212 | best error P = 127082.190476 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSohtawiCoHl'
# Generation  213 | best error P = 127082.190476 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSohtawiCoHl'
# Generation  214 | best error P = 125664.666667 | best text = 'Wrvn Me haeeDThIIIOeN JfVDtriTiSohtawiCoil'
# Generation  215 | best error P = 117238.166667 | best text = 'Wrvn Me haeeDThIIIleN JfVDtriTiSohtawiCoHl'
# Generation  216 | best error P = 117238.166667 | best text = 'Wrvn Me haeeDThIIIleN JfVDtriTiSohtawiCoHl'
# Generation  217 | best error P = 115820.642857 | best text = 'Wrvn Me haeeDThIIIleN JfVDtriTiSohtawiCoil'
# Generation  218 | best error P = 115820.642857 | best text = 'Wrvn Me haeeDThIIIleN JfVDtriTiSohtawiCoil'
# Generation  219 | best error P = 115820.642857 | best text = 'Wrvn Me haeeDThIIIleN JfVDtriTiSohtawiCoil'
# Generation  220 | best error P = 115476.642857 | best text = 'Wrvn Me haeeDThuIIleN JfVDtriTiSohtawiCoHl'
# Generation  221 | best error P = 115476.642857 | best text = 'Wrvn Me haeeDThuIIleN JfVDtriTiSohtawiCoHl'
# Generation  222 | best error P = 111905.428571 | best text = 'Wrvn Me haeeDThIIIleN JfVDtqiTiSohtawiCoHl'
# Generation  223 | best error P = 111905.428571 | best text = 'Wrvn Me haeeDThIIIleN JfVDtqiTiSohtawiCoHl'
# Generation  224 | best error P = 111905.428571 | best text = 'Wrvn Me haeeDThIIIleN JfVDtqiTiSohtawiCoHl'
# Generation  225 | best error P = 111905.428571 | best text = 'Wrvn Me haeeDThIIIleN JfVDtqiTiSohtawiCoHl'
# Generation  226 | best error P = 111905.428571 | best text = 'Wrvn Me haeeDThIIIleN JfVDtqiTiSohtawiCoHl'
# Generation  227 | best error P = 110143.904762 | best text = 'Wrvn Me haeeDThuIIleN JfVDtqiTiSohtawiCoHl'
# Generation  228 | best error P = 98243.119048 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoHl'
# Generation  229 | best error P = 98243.119048 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoHl'
# Generation  230 | best error P = 96825.595238 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  231 | best error P = 96825.595238 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  232 | best error P = 96825.595238 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  233 | best error P = 96825.595238 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  234 | best error P = 96825.595238 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  235 | best error P = 91430.928571 | best text = 'Whvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  236 | best error P = 91430.928571 | best text = 'Whvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  237 | best error P = 91430.928571 | best text = 'Whvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  238 | best error P = 91430.928571 | best text = 'Whvn Me hareDThuIIleN JfVDtqiTiSohtawiCoil'
# Generation  239 | best error P = 91369.000000 | best text = 'Whvn Me hareDThuIIleN JfVDthiTiSohtawiCoil'
# Generation  240 | best error P = 91369.000000 | best text = 'Whvn Me hareDThuIIleN JfVDthiTiSohtawiCoil'
# Generation  241 | best error P = 91369.000000 | best text = 'Whvn Me hareDThuIIleN JfVDthiTiSohtawiCoil'
# Generation  242 | best error P = 82598.714286 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTimohtawiCoil'
# Generation  243 | best error P = 82598.714286 | best text = 'Wrvn Me hareDThuIIleN JfVDtqiTimohtawiCoil'
# Generation  244 | best error P = 76203.452381 | best text = 'Whvn Me hareDThuIIleN ofVDtqiTimohtawiCoil'
# Generation  245 | best error P = 76203.452381 | best text = 'Whvn Me hareDThuIIleN ofVDtqiTimohtawiCoil'
# Generation  246 | best error P = 75199.642857 | best text = 'Whvn Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  247 | best error P = 75199.642857 | best text = 'Whvn Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  248 | best error P = 65240.952381 | best text = 'When Me hareDThuIIleN JfVDthiTimohtawiCoil'
# Generation  249 | best error P = 65240.952381 | best text = 'When Me hareDThuIIleN JfVDthiTimohtawiCoil'
# Generation  250 | best error P = 64302.285714 | best text = 'When Me hareDThuIIleN ofVDtqiTimohtawiCoil'
# Generation  251 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  252 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  253 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  254 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  255 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  256 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  257 | best error P = 63298.476190 | best text = 'When Me hareDThuIIleN ofVDtqiTDmohtawiCoil'
# Generation  258 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  259 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  260 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  261 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  262 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  263 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  264 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  265 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  266 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  267 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  268 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  269 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  270 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  271 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  272 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  273 | best error P = 59757.547619 | best text = 'When Me hareDThuIIleN ofIDtqiTDmohtawiCoil'
# Generation  274 | best error P = 53661.452381 | best text = 'When Me hareDshuIIleN ofIDtqiTDmohtawiCoil'
# Generation  275 | best error P = 53661.452381 | best text = 'When Me hareDshuIIleN ofIDtqiTDmohtawiCoil'
# Generation  276 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  277 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  278 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  279 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  280 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  281 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  282 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  283 | best error P = 52567.380952 | best text = 'When Me hareDshuIIleN ofIDtqiTDmoqtawiCoil'
# Generation  284 | best error P = 52066.785714 | best text = 'When Me hareDshuIIleN offDtqiTDmoqtawiCoil'
# Generation  285 | best error P = 52066.785714 | best text = 'When Me hareDshuIIleN offDtqiTDmoqtawiCoil'
# Generation  286 | best error P = 44433.190476 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawizoil'
# Generation  287 | best error P = 44433.190476 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawizoil'
# Generation  288 | best error P = 44433.190476 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawizoil'
# Generation  289 | best error P = 44433.190476 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawizoil'
# Generation  290 | best error P = 43910.023810 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawiCoil'
# Generation  291 | best error P = 43910.023810 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawiCoil'
# Generation  292 | best error P = 43910.023810 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawiCoil'
# Generation  293 | best error P = 43910.023810 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawiCoil'
# Generation  294 | best error P = 43910.023810 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawiCoil'
# Generation  295 | best error P = 43600.595238 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawicoil'
# Generation  296 | best error P = 43600.595238 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawicoil'
# Generation  297 | best error P = 43600.595238 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawicoil'
# Generation  298 | best error P = 43600.595238 | best text = 'When Me hareDshuIIleN ofIDtqiT moqtawicoil'
# Generation  299 | best error P = 35252.666667 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawiCoil'
# Generation  300 | best error P = 35252.666667 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawiCoil'
# Generation  301 | best error P = 35252.666667 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawiCoil'
# Generation  302 | best error P = 35252.666667 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawiCoil'
# Generation  303 | best error P = 34943.238095 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawicoil'
# Generation  304 | best error P = 34943.238095 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawicoil'
# Generation  305 | best error P = 34943.238095 | best text = 'When Me hareDshuIIleN ofI tqiT moqtawicoil'
# Generation  306 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  307 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  308 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  309 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  310 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  311 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  312 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  313 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  314 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  315 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  316 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  317 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  318 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  319 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  320 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  321 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  322 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  323 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  324 | best error P = 25282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaw coil'
# Generation  325 | best error P = 23282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaU coil'
# Generation  326 | best error P = 23282.071429 | best text = 'When Me hareDshuIIleN ofI tqiT moqtaU coil'
# Generation  327 | best error P = 20981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaw coil'
# Generation  328 | best error P = 20981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaw coil'
# Generation  329 | best error P = 20981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaw coil'
# Generation  330 | best error P = 20981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaw coil'
# Generation  331 | best error P = 20981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaw coil'
# Generation  332 | best error P = 20981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaw coil'
# Generation  333 | best error P = 18981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaU coil'
# Generation  334 | best error P = 18981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaU coil'
# Generation  335 | best error P = 18981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaU coil'
# Generation  336 | best error P = 18981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaU coil'
# Generation  337 | best error P = 18981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaU coil'
# Generation  338 | best error P = 18981.476190 | best text = 'When Me hareDshuIIleN ofI tqiT mortaU coil'
# Generation  339 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  340 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  341 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  342 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  343 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  344 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  345 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  346 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  347 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  348 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  349 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  350 | best error P = 18480.880952 | best text = 'When Me hareDshufIleN ofI tqiT mortaU coil'
# Generation  351 | best error P = 15309.238095 | best text = 'When Me vare shufIleN ofI tqiT mortaU coil'
# Generation  352 | best error P = 15309.238095 | best text = 'When Me vare shufIleN ofI tqiT mortaU coil'
# Generation  353 | best error P = 15309.238095 | best text = 'When Me vare shufIleN ofI tqiT mortaU coil'
# Generation  354 | best error P = 15309.238095 | best text = 'When Me vare shufIleN ofI tqiT mortaU coil'
# Generation  355 | best error P = 15309.238095 | best text = 'When Me vare shufIleN ofI tqiT mortaU coil'
# Generation  356 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  357 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  358 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  359 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  360 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  361 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  362 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  363 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  364 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  365 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  366 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  367 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  368 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  369 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  370 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  371 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  372 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  373 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  374 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  375 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  376 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  377 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  378 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  379 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  380 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  381 | best error P = 9823.523810 | best text = 'When Me hare shufIleN ofI tqiT mortaU coil'
# Generation  382 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  383 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  384 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  385 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  386 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  387 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  388 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  389 | best error P = 9167.428571 | best text = 'When Me hare shufIleN ofI tqiT mortal coil'
# Generation  390 | best error P = 9026.261905 | best text = 'When Me hare shufIled ofI tqiT mortal coil'
# Generation  391 | best error P = 9026.261905 | best text = 'When Me hare shufIled ofI tqiT mortal coil'
# Generation  392 | best error P = 9026.261905 | best text = 'When Me hare shufIled ofI tqiT mortal coil'
# Generation  393 | best error P = 9026.261905 | best text = 'When Me hare shufIled ofI tqiT mortal coil'
# Generation  394 | best error P = 9026.261905 | best text = 'When Me hare shufIled ofI tqiT mortal coil'
# Generation  395 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  396 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  397 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  398 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  399 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  400 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  401 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  402 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  403 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  404 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  405 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  406 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  407 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  408 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  409 | best error P = 8666.833333 | best text = 'When Me hare shufIleN off tqiT mortal coil'
# Generation  410 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  411 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  412 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  413 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  414 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  415 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  416 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  417 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  418 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  419 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  420 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  421 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  422 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  423 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  424 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  425 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  426 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  427 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  428 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  429 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  430 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  431 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  432 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  433 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  434 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  435 | best error P = 8525.666667 | best text = 'When Me hare shufIled off tqiT mortal coil'
# Generation  436 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  437 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  438 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  439 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  440 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  441 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  442 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  443 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  444 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  445 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  446 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  447 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  448 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  449 | best error P = 2429.571429 | best text = 'When Me hare shufIled off tqis mortal coil'
# Generation  450 | best error P = 1928.976190 | best text = 'When Me hare shuffled off tqis mortal coil'
# Generation  451 | best error P = 562.904762 | best text = 'When we hare shufIled off tqis mortal coil'
# Generation  452 | best error P = 562.904762 | best text = 'When we hare shufIled off tqis mortal coil'
# Generation  453 | best error P = 562.904762 | best text = 'When we hare shufIled off tqis mortal coil'
# ...
# Generation  591 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  592 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  593 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  594 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  595 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  596 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  597 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  598 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  599 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  600 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  601 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  602 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  603 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  604 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  605 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  606 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  607 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  608 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  609 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  610 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  611 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  612 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  613 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  614 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  615 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  616 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  617 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  618 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  619 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  620 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  621 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  622 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  623 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  624 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  625 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  626 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  627 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  628 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  629 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  630 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  631 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  632 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  633 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  634 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  635 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  636 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  637 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  638 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  639 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  640 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  641 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  642 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  643 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  644 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  645 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  646 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  647 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  648 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  649 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  650 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  651 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  652 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  653 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  654 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  655 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  656 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  657 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  658 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  659 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  660 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  661 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  662 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  663 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  664 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  665 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  666 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  667 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  668 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  669 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  670 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  671 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  672 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  673 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  674 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  675 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  676 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  677 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  678 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  679 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  680 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  681 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  682 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  683 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  684 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  685 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  686 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  687 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  688 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  689 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  690 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  691 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  692 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  693 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  694 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  695 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  696 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  697 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  698 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  699 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  700 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  701 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  702 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  703 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  704 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  705 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  706 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  707 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  708 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  709 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  710 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  711 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  712 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  713 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  714 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  715 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  716 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  717 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  718 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  719 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  720 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  721 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  722 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  723 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  724 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  725 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  726 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  727 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  728 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  729 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  730 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  731 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  732 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  733 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  734 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  735 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  736 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  737 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  738 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  739 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  740 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  741 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  742 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  743 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  744 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  745 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  746 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  747 | best error P = 0.380952 | best text = 'When we hare shuffled off this mortal coil'
# Generation  748 | best error P = 0.000000 | best text = 'When we have shuffled off this mortal coil'
# Exact match found, stopping.

# %% [markdown]
# Now check the result by decrypting the ciphertext with the found plaintext.
# Assuming we have factored n to find p and q, and computed d.

# %%
# factoring n to find p and q
p, q = 149, 223          # 149 * 223 = 33227
phi = (p - 1) * (q - 1)
# find d, the modular inverse of e mod phi
def egcd(a, b):
    if b == 0:
        return (1, 0, a)
    x, y, g = egcd(b, a % b)
    return (y, x - (a // b) * y, g)

x, y, g = egcd(public_key, phi)
d = x % phi              # private exponent

#  decrypting the ciphertext
plaintext_chars = [chr(pow(c, d, n)) for c in ciphertext]
plaintext = "".join(plaintext_chars)
print(plaintext)
# Out:
# When we have shuffled off this mortal coil
