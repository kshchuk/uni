# %% [markdown]
# Goal: Use a simple genetic algorithm (as in Holland’s and Goldberg’s “simple GA”) to approximate the unknown plaintext a such that
# rsa_lib.encrypt_text(candidate, public_key, n) is as close as possible to the given ciphertext b.

# %%
import random
from pathlib import Path

# Import your RSA library
from var import rsa_lib

# %%
# Directly from 8_encrypted_text.txt (variant 8)
ciphertext = [4012, 216, 1403, 10437, 8192, 15617, 1403, 8192, 216, 17270, 696, 1403, 8192, 12593, 216, 19224, 18807, 18807, 15951, 1403, 13821, 8192, 11101, 18807, 18807, 8192, 20733, 216, 7555, 12593, 8192, 31197, 11101, 692, 20733, 17270, 15951, 8192, 30299, 11101, 7555, 15951]

public_key = 65537
n = 33227

len(ciphertext), public_key, n
# Out:
# (42, 65537, 33227)

# %%
ALPHABET = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ, "
ALPHABET_SIZE = len(ALPHABET)
TEXT_LENGTH = 42  # must match the length of the unknown plaintext

# %%
def random_char():
    return random.choice(ALPHABET)

def random_text(length=TEXT_LENGTH):
    return "".join(random_char() for _ in range(length))

# %%
def encrypt_candidate(text):
    """
    Encrypt candidate plaintext using the given rsa_lib.
    Returns a list (or iterable) of integers.
    """
    return rsa_lib.encrypt_text(text, public_key, n)

# %% [markdown]
# Define the error \( P \) and fitness:
#
# $$
# P(x, b) = \frac{1}{n} \sum_{i=1}^n (b'_i - b_i)^2
# $$
#
# and convert this to a fitness to maximize, e.g.:
#
# $$
# \text{F}(x) = \frac{1}{1 + P(x, b)}
# $$

# %%
def error_P(candidate_text, target_cipher):
    cand_cipher = encrypt_candidate(candidate_text)

    # Safety: use min length if for some reason they differ
    L = min(len(cand_cipher), len(target_cipher))
    s = 0.0
    for i in range(L):
        diff = cand_cipher[i] - target_cipher[i]
        s += diff * diff
    return s / L

def fitness(candidate_text, target_cipher):
    P = error_P(candidate_text, target_cipher)
    return 1.0 / (1.0 + P)  # smaller error -> larger fitness

# %% [markdown]
# Initialize the population

# %%
POP_SIZE = 100

def initialize_population():
    return [random_text(TEXT_LENGTH) for _ in range(POP_SIZE)]

population = initialize_population()
len(population), population[0][:10]
# Out:
# (100, 'gfQfMYrrKa')

# %% [markdown]
# Selection operator (tournament selection)

# %%
def tournament_select(population, fitnesses, tournament_size=3):
    """
    Return one selected individual from population using tournament selection.
    """
    selected_idx = random.randrange(len(population))
    for _ in range(tournament_size - 1):
        i = random.randrange(len(population))
        if fitnesses[i] > fitnesses[selected_idx]:
            selected_idx = i
    return population[selected_idx]

# %% [markdown]
# Crossover operator (one-point crossover on strings)

# %%
def one_point_crossover(parent1, parent2):
    assert len(parent1) == len(parent2)
    L = len(parent1)
    if L < 2:
        return parent1, parent2
    cut = random.randint(1, L - 1)  # cut point between 1 and L-1
    child1 = parent1[:cut] + parent2[cut:]
    child2 = parent2[:cut] + parent1[cut:]
    return child1, child2

# %% [markdown]
# Mutation operator ( with small probability per position, change a character to a random other character from the alphabet)

# %%
MUTATION_RATE = 0.02  # probability of mutating each character

def mutate(text):
    text_list = list(text)
    for i in range(len(text_list)):
        if random.random() < MUTATION_RATE:
            text_list[i] = random_char()
    return "".join(text_list)

# %% [markdown]
# One GA generation (with elitism)

# %%
CROSSOVER_RATE = 0.8
ELITE_COUNT = 2  # number of best individuals preserved each generation

# %%
def make_next_generation(population, target_cipher):
    # 1. Evaluate current population
    fitnesses = [fitness(ind, target_cipher) for ind in population]

    # 2. Sort by fitness (descending)
    pop_fit = list(zip(population, fitnesses))
    pop_fit.sort(key=lambda x: x[1], reverse=True)

    # 3. Elites
    new_population = [ind for ind, fit in pop_fit[:ELITE_COUNT]]

    # 4. Generate the rest via selection, crossover, mutation
    while len(new_population) < POP_SIZE:
        # Parent selection
        parent1 = tournament_select(population, fitnesses)
        parent2 = tournament_select(population, fitnesses)

        # Crossover
        if random.random() < CROSSOVER_RATE:
            child1, child2 = one_point_crossover(parent1, parent2)
        else:
            child1, child2 = parent1, parent2

        # Mutation
        child1 = mutate(child1)
        child2 = mutate(child2)

        new_population.append(child1)
        if len(new_population) < POP_SIZE:
            new_population.append(child2)

    # Also return current best individual for logging
    best_ind, best_fit = pop_fit[0]
    return new_population, best_ind, best_fit

# %%
MAX_GENERATIONS = 20000
TARGET_ERROR_THRESHOLD = 0.0  # stop if exact match is found

population = initialize_population()

for generation in range(MAX_GENERATIONS):
    # Evaluate and evolve
    population, best_ind, best_fit = make_next_generation(population, ciphertext)

    # Compute error explicitly for reporting
    best_error = error_P(best_ind, ciphertext)

    # REQUIRED OUTPUT: best current result for this iteration
    print(f"Generation {generation:4d} | best error P = {best_error:.6f} | best text = {repr(best_ind)}")

    # Stop if we hit perfect match (P = 0)
    if best_error <= TARGET_ERROR_THRESHOLD:
        print("Exact match found, stopping.")
        break
# Out:
# Generation    0 | best error P = 110582079.357143 | best text = 'XlqZVQvxlOWEGsxADgMrXQJLwbPCrfuGGrYCvJBuLl'
# Generation    1 | best error P = 93773573.666667 | best text = 'XlqZGQvxlOWEJsxADgMrXlE,ixEuIKITUvqIHUzFAd'
# Generation    2 | best error P = 92449354.071429 | best text = 'RiDxzalH afeHv PgTpdyOHdgZpWqx MMPyLHlkfmo'
# Generation    3 | best error P = 76312481.714286 | best text = 'XlqZVQvxlOWEGsxADgMrgRzYClXvpWDzEownw FPGs'
# Generation    4 | best error P = 60345633.452381 | best text = 'GqqQ pGR afeHv PgTpdyOHdgZpWqx zEownw mGvs'
# Generation    5 | best error P = 58512240.119048 | best text = 'XlqZGQvxlOWeHv PgTpdyOHdgZpWqx zEownw mGvs'
# Generation    6 | best error P = 58512240.119048 | best text = 'XlqZGQvxlOWeHv PgTpdyOHdgZpWqx zEownw mGvs'
# Generation    7 | best error P = 48329560.833333 | best text = 'Z NivDvxlOWEGsxADgMrgRHdgZpWqx zEownw mGvs'
# Generation    8 | best error P = 42267223.047619 | best text = 'WqqQ pGR OWEGsxAagMrXOHUgZpWqx zEownw myvs'
# Generation    9 | best error P = 41397739.095238 | best text = 'Z NivDvx OWEGsxAagMrXOHUgZpWqx zEownw myvs'
# Generation   10 | best error P = 41397739.095238 | best text = 'Z NivDvx OWEGsxAagMrXOHUgZpWqx zEownw myvs'
# Generation   11 | best error P = 39717322.333333 | best text = 'RiNlnQvxlOWeHv PgTOrgRHdgZpWqx zEownw mGvs'
# Generation   12 | best error P = 35823736.476190 | best text = 'WqqQ QvxlOWeHv PgTOhgRHdgZpWqx zEownw mGvs'
# Generation   13 | best error P = 32659604.333333 | best text = 'WqqQ Qvx OWEGsxwagMrXOHUgZpWRx zEownw mGvV'
# Generation   14 | best error P = 27066028.452381 | best text = 'WqqQ Qvx OWEHF PagMrXOHUgZpWRx zEownU mGvs'
# Generation   15 | best error P = 25901112.952381 | best text = 'WqqQ Qvx OWEHF wagMrXOHUgZpWRx zEownU mGvs'
# Generation   16 | best error P = 24859483.357143 | best text = 'WqqQvQvx OWEHsrAagMrdOHUgxpWqx zEownw mGvs'
# Generation   17 | best error P = 24859483.357143 | best text = 'WqqQvQvx OWEHsrAagMrdOHUgxpWqx zEownw mGvs'
# Generation   18 | best error P = 24244385.952381 | best text = 'WqqQ Qvx OWEHFrPagMrXOHUgZpWqx zEownw msvV'
# Generation   19 | best error P = 21703490.714286 | best text = 'WqqQ Qvx OWEHF AagMrdOHUgxpWqx zEowfw mPvV'
# Generation   20 | best error P = 19663076.047619 | best text = 'WqqQoQvx OWEHsrAafMrdOHUgxpWqx zEowfw mPvs'
# Generation   21 | best error P = 19403572.047619 | best text = 'WqqQoQvx OWEHsrAafMrdOHUgxpWqx zEowfw mPvM'
# Generation   22 | best error P = 18317360.523810 | best text = 'WqqQ Qvx OWeHlhAasMrdOHUgxxWqx zEowfw mPvV'
# Generation   23 | best error P = 18143667.261905 | best text = 'WqqQoQvx OWEHsrAafMrdOHUgxpWqx zEhwnw mJvs'
# Generation   24 | best error P = 16684574.238095 | best text = 'Wqqn Qvx OWEHFrAagMrdOHUgxxWqx zEowfw mPvV'
# Generation   25 | best error P = 14991361.428571 | best text = 'Wqqs xvx OWeHsrAafMrdOHUgxjWqx zEowfw mJvV'
# Generation   26 | best error P = 12579127.523810 | best text = 'eqqs xvx OWeHsrAafMrdOHUgxjWqx zEhwfw mJvV'
# Generation   27 | best error P = 12579127.523810 | best text = 'eqqs xvx OWeHsrAafMrdOHUgxjWqx zEhwfw mJvV'
# Generation   28 | best error P = 12416997.000000 | best text = 'Whqs xvx OWeHsrAafMrdOHUgxjWqx zEhwfw mJvV'
# Generation   29 | best error P = 11582798.285714 | best text = 'Whqs xvx OWeHsrAafMrdyHUgxjWqx zEhwfw mJvZ'
# Generation   30 | best error P = 11582798.285714 | best text = 'Whqs xvx OWeHsrAafMrdyHUgxjWqx zEhwfw mJvZ'
# Generation   31 | best error P = 9426308.642857 | best text = 'Wqqs xvp OWeHsrAafMrdiHUgxOWqx zEhwfw mJvZ'
# Generation   32 | best error P = 9426308.642857 | best text = 'Wqqs xvp OWeHsrAafMrdiHUgxOWqx zEhwfw mJvZ'
# Generation   33 | best error P = 9426308.642857 | best text = 'Wqqs xvp OWeHsrAafMrdiHUgxOWqx zEhwfw mJvZ'
# Generation   34 | best error P = 9291978.404762 | best text = 'Wqqs xvp OWelsrAafMrdiHUgxjWRx zEhwfw mJHZ'
# Generation   35 | best error P = 8874450.333333 | best text = 'erqs xvxvOWeHsrAafMrdiHUgxOWqx zEhwfw mJvZ'
# Generation   36 | best error P = 8307586.142857 | best text = 'Wqqs xvp OWeHsrAafMrdiHUgxOWqx zEhwfw mJHZ'
# Generation   37 | best error P = 7273892.785714 | best text = 'erqs xvxvOWeHsrAafMrdiHUgojWqZ zsewGw mJHZ'
# Generation   38 | best error P = 7054901.571429 | best text = 'erqs xvxvOWeHsrAafMrdiHUgojWqZ zsewfw mJHZ'
# Generation   39 | best error P = 6743955.523810 | best text = 'eqq  xvPvOWeHDrAafMrdiHUgojWqZ zsewfw mJHZ'
# Generation   40 | best error P = 6075862.357143 | best text = 'erqs xvxvOWeHsrAafMrdiHUgoOWExFzEqwfw mJHZ'
# Generation   41 | best error P = 6075862.357143 | best text = 'erqs xvxvOWeHsrAafMrdiHUgoOWExFzEqwfw mJHZ'
# Generation   42 | best error P = 5718350.142857 | best text = 'WhqP xvxvdWeHPrfafMrdiHUgoOWExFzEqwfw mJHZ'
# Generation   43 | best error P = 5174577.738095 | best text = 'eqq  xvPvOyeHsrAafMrdiHUgoOWEdFzEqwfw mJHZ'
# Generation   44 | best error P = 4821740.452381 | best text = 'erqs xvxvOWeHsrAafMrdiHUgoOWEZ zseVfw mJHZ'
# Generation   45 | best error P = 4485778.238095 | best text = 'eqq  xvPvOyeHsrAafMrdiHUgoOWEA zsewfw mJHa'
# Generation   46 | best error P = 4439926.404762 | best text = 'eqqs xvPvOyeHsrAafMrdiHUgoOWEZ zsewfw mJHZ'
# Generation   47 | best error P = 4155430.761905 | best text = 'Wqrn xvPvOyeHsrAafMrdiHUgoOWEd zsewfw mJHZ'
# Generation   48 | best error P = 4027102.619048 | best text = 'Wqrn xvPvOyeHsrAaGMrdiHUgoOWEZ zHeVfw mJHZ'
# Generation   49 | best error P = 3655464.404762 | best text = 'Wqrn xvPvOyeHsrAafMrdiHUgoOWEZ zseVfw mJHZ'
# Generation   50 | best error P = 3655464.404762 | best text = 'Wqrn xvPvOyeHsrAafMrdiHUgoOWEZ zseVfw mJHZ'
# Generation   51 | best error P = 3230764.904762 | best text = 'Wrqs xvPvOyeHsrAafardiFUNoOWEZ zseVfw mJHZ'
# Generation   52 | best error P = 2984872.404762 | best text = 'eqq  xvPvOyeHsrQafardiFUNoOWEZ zseVfw mJHZ'
# Generation   53 | best error P = 2984872.404762 | best text = 'eqq  xvPvOyeHsrQafardiFUNoOWEZ zseVfw mJHZ'
# Generation   54 | best error P = 2428604.047619 | best text = 'Wrqs xvivOyeHsrAafardiFUfoOWEZ zseVfw mJHZ'
# Generation   55 | best error P = 2428604.047619 | best text = 'Wrqs xvivOyeHsrAafardiFUfoOWEZ zseVfw mJHZ'
# Generation   56 | best error P = 2345509.142857 | best text = 'Wqrn xvPvOyeHsrQafardDFUNoOvEZ zseVfw mJHZ'
# Generation   57 | best error P = 2109340.928571 | best text = 'Wqrn xvPvOyeHsrQafardDFUfoOWEZ zseVfw mJHZ'
# Generation   58 | best error P = 2109340.928571 | best text = 'Wqrn xvPvOyeHsrQafardDFUfoOWEZ zseVfw mJHZ'
# Generation   59 | best error P = 2109340.928571 | best text = 'Wqrn xvPvOyeHsrQafardDFUfoOWEZ zseVfw mJHZ'
# Generation   60 | best error P = 2097307.642857 | best text = 'Wqrn xvnvOyeHsrQafardDFUNoOvEZ zsetfw mJHZ'
# Generation   61 | best error P = 2046889.214286 | best text = 'Wqqs xvivOeeHsrAafardiFUfoOvEZ zseVfw mJHZ'
# Generation   62 | best error P = 1991288.095238 | best text = 'Wqrn xvnvOyeHsrQafardDFUfoOWEZ zseVfw mJHZ'
# Generation   63 | best error P = 1982143.833333 | best text = 'Wqrn xvnvOyeHsrQafardiFUfoOWEZ zsetfwnmJHZ'
# Generation   64 | best error P = 1912615.571429 | best text = 'Wqqs xvnvOyeHsrQafarsiTUfoOvEZ zseVfw mJHZ'
# Generation   65 | best error P = 1771740.547619 | best text = 'Wqrn xvPvOyeHsrQafardDFUfoOvEZ zseVfw mJHZ'
# Generation   66 | best error P = 1759704.333333 | best text = 'Wqrn xvPvOyeHsrQafaedDFUfoOvEZ zseVfw mJHZ'
# Generation   67 | best error P = 1653907.404762 | best text = 'Wqqs xvnvOyeHsrQafardiFUfoOvEZ zsetfw mJHZ'
# Generation   68 | best error P = 1593598.809524 | best text = 'Wqrn xvnvwyeHsrVafardDFUfoOvEZ zsetfw mJHZ'
# Generation   69 | best error P = 1593598.809524 | best text = 'Wqrn xvnvwyeHsrVafardDFUfoOvEZ zsetfw mJHZ'
# Generation   70 | best error P = 1512116.523810 | best text = 'Wqrn xvnvwyeHsrVafardDFUfnOvEZ zsetfw mJHZ'
# Generation   71 | best error P = 1512116.523810 | best text = 'Wqrn xvnvwyeHsrVafardDFUfnOvEZ zsetfw mJHZ'
# Generation   72 | best error P = 1469052.761905 | best text = 'Wqrn xvnvOyeHsrVafardDFUfnOvEZ zsetIw mJHZ'
# Generation   73 | best error P = 1336084.142857 | best text = 'Wqrn xvnvOyeHsrVafardDFUInavEZ zsetfw mJHZ'
# Generation   74 | best error P = 1336084.142857 | best text = 'Wqrn xvnvOyeHsrVafardDFUInavEZ zsetfw mJHZ'
# Generation   75 | best error P = 1336084.142857 | best text = 'Wqrn xvnvOyeHsrVafardDFUInavEZ zsetfw mJHZ'
# Generation   76 | best error P = 1226120.619048 | best text = 'Wqrn xvnvOyeHsrQatardiFUfotvEZ zsetfw mJHV'
# Generation   77 | best error P = 1147390.333333 | best text = 'Wqrn xvnvwreHTrQafardiFUfotvEZ zsetfw mJHV'
# Generation   78 | best error P = 1104322.428571 | best text = 'Wqrn xvnvwyeHsrVafardDFUfnGvEZ zsetfw mJHZ'
# Generation   79 | best error P = 1035171.976190 | best text = 'Wqrn xvnvOyeHsrQafardiFUfntvEZ zsetfw mJHZ'
# Generation   80 | best error P = 1035171.976190 | best text = 'Wqrn xvnvOyeHsrQafardiFUfntvEZ zsetfw mJHZ'
# Generation   81 | best error P = 951580.952381 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfnGvEZ zsetfw mJHZ'
# Generation   82 | best error P = 951580.952381 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfnGvEZ zsetfw mJHZ'
# Generation   83 | best error P = 951580.952381 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfnGvEZ zsetfw mJHZ'
# Generation   84 | best error P = 951580.952381 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfnGvEZ zsetfw mJHZ'
# Generation   85 | best error P = 840237.714286 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   86 | best error P = 840237.714286 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   87 | best error P = 840237.714286 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   88 | best error P = 840237.714286 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   89 | best error P = 836788.928571 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGvEZ zsetUw mJHV'
# Generation   90 | best error P = 834813.928571 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGqEZ zsetfw mJHZ'
# Generation   91 | best error P = 829357.333333 | best text = 'Wqrn xvnvayeHsrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   92 | best error P = 829357.333333 | best text = 'Wqrn xvnvayeHsrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   93 | best error P = 795651.309524 | best text = 'Wqrn xvnvOreHTrQufOrdiFUfDGvEZ zsetfw mJHZ'
# Generation   94 | best error P = 741332.452381 | best text = 'Wqhn xvnvOyeHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation   95 | best error P = 719821.785714 | best text = 'Wqrn xvnvOyeHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation   96 | best error P = 675235.380952 | best text = 'Wqrn xvnvOreHTrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation   97 | best error P = 675235.380952 | best text = 'Wqrn xvnvOreHTrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation   98 | best error P = 669139.285714 | best text = 'Wqrn xvnvOreHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation   99 | best error P = 669139.285714 | best text = 'Wqrn xvnvOreHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation  100 | best error P = 669139.285714 | best text = 'Wqrn xvnvOreHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation  101 | best error P = 669139.285714 | best text = 'Wqrn xvnvOreHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation  102 | best error P = 669139.285714 | best text = 'Wqrn xvnvOreHsrQufOrdiFUfDGvEZ zsetfw mJHU'
# Generation  103 | best error P = 496851.190476 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zsetfw mJHU'
# Generation  104 | best error P = 496851.190476 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zsetfw mJHU'
# Generation  105 | best error P = 496851.190476 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zsetfw mJHU'
# Generation  106 | best error P = 491427.404762 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGqEZ zsetfw mJHU'
# Generation  107 | best error P = 453430.190476 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  108 | best error P = 453430.190476 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  109 | best error P = 441393.976190 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zFrtfO mJHU'
# Generation  110 | best error P = 441393.976190 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zFrtfO mJHU'
# Generation  111 | best error P = 441393.976190 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zFrtfO mJHU'
# Generation  112 | best error P = 441393.976190 | best text = 'Wqrn xvnvOreHsrQufOrdiFffDGvEZ zFrtfO mJHU'
# Generation  113 | best error P = 342086.952381 | best text = 'Wqrn xvDvOreHsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  114 | best error P = 304393.595238 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  115 | best error P = 304393.595238 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  116 | best error P = 304393.595238 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  117 | best error P = 295205.666667 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfU mJHU'
# Generation  118 | best error P = 295205.666667 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfU mJHU'
# Generation  119 | best error P = 295205.666667 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfU mJHU'
# Generation  120 | best error P = 295205.666667 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfU mJHU'
# Generation  121 | best error P = 295205.666667 | best text = 'Wqrn MvDvOreHsrQufOrdiFffDGvEZ zFetfU mJHU'
# Generation  122 | best error P = 294570.928571 | best text = 'Wqrn MvDvOreDsrQufOrdiFffDGvEZ zFetfO mJHU'
# Generation  123 | best error P = 284909.761905 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFetfO mJHU'
# Generation  124 | best error P = 275721.833333 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFetfU mJHU'
# Generation  125 | best error P = 260788.714286 | best text = 'Wqrn MvDvOreDsrQufOrdiFffDGvEZ zFetUU mJHU'
# Generation  126 | best error P = 260788.714286 | best text = 'Wqrn MvDvOreDsrQufOrdiFffDGvEZ zFetUU mJHU'
# Generation  127 | best error P = 260788.714286 | best text = 'Wqrn MvDvOreDsrQufOrdiFffDGvEZ zFetUU mJHU'
# Generation  128 | best error P = 260788.714286 | best text = 'Wqrn MvDvOreDsrQufOrdiFffDGvEZ zFetUU mJHU'
# Generation  129 | best error P = 251127.547619 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  130 | best error P = 251127.547619 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  131 | best error P = 251127.547619 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  132 | best error P = 251127.547619 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  133 | best error P = 248734.952381 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zoetUU mJHU'
# Generation  134 | best error P = 245703.761905 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  135 | best error P = 245703.761905 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  136 | best error P = 245703.761905 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGvEZ zFetUU mJHU'
# Generation  137 | best error P = 243311.166667 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGvEZ zoetUU mJHU'
# Generation  138 | best error P = 239091.333333 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGvEZ zFrtUU mJHU'
# Generation  139 | best error P = 233667.547619 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGvEZ zFrtUU mJHU'
# Generation  140 | best error P = 233667.547619 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGvEZ zFrtUU mJHU'
# Generation  141 | best error P = 225356.023810 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGv Z zoetUU mJHU'
# Generation  142 | best error P = 219932.238095 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv Z zoetUU mJHU'
# Generation  143 | best error P = 215712.404762 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGv Z zFrtUU mJHU'
# Generation  144 | best error P = 215712.404762 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGv Z zFrtUU mJHU'
# Generation  145 | best error P = 215712.404762 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGv Z zFrtUU mJHU'
# Generation  146 | best error P = 213410.857143 | best text = 'Wqrn MvDvOreDsvQufOrd FffDGv Z zortUU mJHU'
# Generation  147 | best error P = 213410.857143 | best text = 'Wqrn MvDvOreDsvQufOrd FffDGv Z zortUU mJHU'
# Generation  148 | best error P = 207896.023810 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv Z zortUU mJHU'
# Generation  149 | best error P = 207896.023810 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv Z zortUU mJHU'
# Generation  150 | best error P = 207896.023810 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv Z zortUU mJHU'
# Generation  151 | best error P = 184352.928571 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGv s zortUU mJHU'
# Generation  152 | best error P = 184352.928571 | best text = 'Wqrn MvDvOreDsrQufOrd FffDGv s zortUU mJHU'
# Generation  153 | best error P = 178929.142857 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv s zortUU mJHU'
# Generation  154 | best error P = 178929.142857 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv s zortUU mJHU'
# Generation  155 | best error P = 178929.142857 | best text = 'Wqrn MvDqOreDsrQufOrd FffDGv s zortUU mJHU'
# Generation  156 | best error P = 178449.047619 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortUU mJHU'
# Generation  157 | best error P = 178449.047619 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortUU mJHU'
# Generation  158 | best error P = 178449.047619 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortUU mJHU'
# Generation  159 | best error P = 178449.047619 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortUU mJHU'
# Generation  160 | best error P = 178449.047619 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortUU mJHU'
# Generation  161 | best error P = 146796.452381 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortaU mJHU'
# Generation  162 | best error P = 146796.452381 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortaU mJHU'
# Generation  163 | best error P = 146796.452381 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortaU mJHU'
# Generation  164 | best error P = 146796.452381 | best text = 'Wqrn MvDqOreDsruufOrd FffDGv s zortaU mJHU'
# Generation  165 | best error P = 138139.095238 | best text = 'Wqrn MvDqOre sruufOrd FffDGv s zortaU mJHU'
# Generation  166 | best error P = 138139.095238 | best text = 'Wqrn MvDqOre sruufOrd FffDGv s zortaU mJHU'
# Generation  167 | best error P = 138139.095238 | best text = 'Wqrn MvDqOre sruufOrd FffDGv s zortaU mJHU'
# Generation  168 | best error P = 138139.095238 | best text = 'Wqrn MvDqOre sruufOrd FffDGv s zortaU mJHU'
# Generation  169 | best error P = 138139.095238 | best text = 'Wqrn MvDqOre sruufOrd FffDGv s zortaU mJHU'
# Generation  170 | best error P = 138139.095238 | best text = 'Wqrn MvDqOre sruufOrd FffDGv s zortaU mJHU'
# Generation  171 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  172 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  173 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  174 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  175 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  176 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  177 | best error P = 132744.428571 | best text = 'Wqrn MvDqOre shuufOrd FffDGv s zortaU mJHU'
# Generation  178 | best error P = 130951.166667 | best text = 'Wqrn MvDqOre sruufwrd FffDGv s zortaU mJHU'
# Generation  179 | best error P = 130951.166667 | best text = 'Wqrn MvDqOre sruufwrd FffDGv s zortaU mJHU'
# Generation  180 | best error P = 130951.166667 | best text = 'Wqrn MvDqOre sruufwrd FffDGv s zortaU mJHU'
# Generation  181 | best error P = 130951.166667 | best text = 'Wqrn MvDqOre sruufwrd FffDGv s zortaU mJHU'
# Generation  182 | best error P = 125556.500000 | best text = 'Wqrn MvDqOre shuufwrd FffDGv s zortaU mJHU'
# Generation  183 | best error P = 124087.071429 | best text = 'Wqrn Mv qOre shuufOrd FffDGv s zortaU mJHU'
# Generation  184 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  185 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  186 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  187 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  188 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  189 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  190 | best error P = 108672.000000 | best text = 'Wqen MvDqOre shuufOed FffDGv s zortaU mJHU'
# Generation  191 | best error P = 101484.071429 | best text = 'Wqen MvDqOre shuufwed FffDGv s zortaU mJHU'
# Generation  192 | best error P = 101484.071429 | best text = 'Wqen MvDqOre shuufwed FffDGv s zortaU mJHU'
# Generation  193 | best error P = 101484.071429 | best text = 'Wqen MvDqOre shuufwed FffDGv s zortaU mJHU'
# Generation  194 | best error P = 101484.071429 | best text = 'Wqen MvDqOre shuufwed FffDGv s zortaU mJHU'
# Generation  195 | best error P = 100014.642857 | best text = 'Wqen Mv qOre shuufOed FffDGv s zortaU mJHU'
# Generation  196 | best error P = 92826.714286 | best text = 'Wqen Mv qOre shuufwed FffDGv s zortaU mJHU'
# Generation  197 | best error P = 92826.714286 | best text = 'Wqen Mv qOre shuufwed FffDGv s zortaU mJHU'
# Generation  198 | best error P = 89402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaw mJHU'
# Generation  199 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  200 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  201 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  202 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  203 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  204 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  205 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  206 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  207 | best error P = 87402.928571 | best text = 'Wqen Mv qOre shuufwed FffDGq s zortaU mJHU'
# Generation  208 | best error P = 86534.357143 | best text = 'Wqen Mv qOre shuufwed PffDGq s zortaU mJHU'
# Generation  209 | best error P = 86534.357143 | best text = 'Wqen Mv qOre shuufwed PffDGq s zortaU mJHU'
# Generation  210 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  211 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  212 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  213 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  214 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  215 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  216 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  217 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  218 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  219 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  220 | best error P = 83763.309524 | best text = 'Wqen Mv qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  221 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  222 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  223 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  224 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  225 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  226 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  227 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  228 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  229 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  230 | best error P = 71862.142857 | best text = 'Wqen Me qOre shuIfwed FffDGq s zortaU mJHU'
# Generation  231 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  232 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  233 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  234 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  235 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  236 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  237 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  238 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  239 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  240 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  241 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  242 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  243 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  244 | best error P = 69206.047619 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU mJHU'
# Generation  245 | best error P = 50005.952381 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU cJHU'
# Generation  246 | best error P = 50005.952381 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU cJHU'
# Generation  247 | best error P = 50005.952381 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU cJHU'
# Generation  248 | best error P = 50005.952381 | best text = 'Wqen Me qOre shuIfled FffDGq s zortaU cJHU'
# Generation  249 | best error P = 39125.571429 | best text = 'Wqen Me qare shuIfled FffDGq s zortaU cJHU'
# Generation  250 | best error P = 39125.571429 | best text = 'Wqen Me qare shuIfled FffDGq s zortaU cJHU'
# Generation  251 | best error P = 39125.571429 | best text = 'Wqen Me qare shuIfled FffDGq s zortaU cJHU'
# Generation  252 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  253 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  254 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  255 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  256 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  257 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  258 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  259 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  260 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  261 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  262 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  263 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  264 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  265 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  266 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  267 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  268 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  269 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  270 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  271 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  272 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  273 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  274 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  275 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  276 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  277 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  278 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  279 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  280 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  281 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  282 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  283 | best error P = 37733.571429 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJHU'
# Generation  284 | best error P = 37077.476190 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJHU'
# Generation  285 | best error P = 37077.476190 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJHU'
# Generation  286 | best error P = 37077.476190 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJHU'
# Generation  287 | best error P = 37077.476190 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJHU'
# Generation  288 | best error P = 36316.047619 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJiU'
# Generation  289 | best error P = 36316.047619 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJiU'
# Generation  290 | best error P = 36316.047619 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJiU'
# Generation  291 | best error P = 36316.047619 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJiU'
# Generation  292 | best error P = 36316.047619 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJiU'
# Generation  293 | best error P = 36316.047619 | best text = 'Wqen Me qare shuIfled JffDGq s zortaU cJiU'
# Generation  294 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  295 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  296 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  297 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  298 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  299 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  300 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  301 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  302 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  303 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  304 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  305 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  306 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  307 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  308 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  309 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  310 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  311 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  312 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  313 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  314 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  315 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  316 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  317 | best error P = 35659.952381 | best text = 'Wqen Me qare shuIfled JffDGq s zortal cJiU'
# Generation  318 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  319 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  320 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  321 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  322 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  323 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  324 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  325 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  326 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  327 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  328 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  329 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  330 | best error P = 25998.785714 | best text = 'Wqen Me qare shuIfled JffDGqis zortal cJiU'
# Generation  331 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  332 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  333 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  334 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  335 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  336 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  337 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  338 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  339 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  340 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  341 | best error P = 24998.190476 | best text = 'Wqen Me qare shuIfled JffDGqis zortal coiU'
# Generation  342 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  343 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  344 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  345 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  346 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  347 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  348 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  349 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  350 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  351 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  352 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  353 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  354 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  355 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  356 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  357 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  358 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  359 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  360 | best error P = 24903.690476 | best text = 'Wqen Me qare shuIfled JffDtqis zortal coiU'
# Generation  361 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  362 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  363 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  364 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  365 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  366 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  367 | best error P = 16246.333333 | best text = 'Wqen Me qare shuIfled Jff tqis zortal coiU'
# Generation  368 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  369 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  370 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  371 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  372 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  373 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  374 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  375 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  376 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  377 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  378 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  379 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  380 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  381 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  382 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  383 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  384 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  385 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  386 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  387 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  388 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  389 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  390 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  391 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  392 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  393 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  394 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  395 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  396 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  397 | best error P = 16245.952381 | best text = 'Wqen Me qave shuIfled Jff tqis zortal coiU'
# Generation  398 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  399 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  400 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  401 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  402 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  403 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  404 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  405 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  406 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  407 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  408 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  409 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  410 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  411 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  412 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  413 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  414 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  415 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  416 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  417 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  418 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  419 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  420 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  421 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  422 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  423 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  424 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  425 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  426 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  427 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  428 | best error P = 16184.023810 | best text = 'Wqen Me have shuIfled Jff tqis zortal coiU'
# Generation  429 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  430 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  431 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  432 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  433 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  434 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  435 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  436 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  437 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  438 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  439 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  440 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  441 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  442 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  443 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  444 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  445 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  446 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  447 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  448 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  449 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  450 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  451 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  452 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# Generation  453 | best error P = 16122.095238 | best text = 'Wqen Me have shuIfled Jff this zortal coiU'
# ...
# Generation  607 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  608 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  609 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  610 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  611 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  612 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  613 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  614 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  615 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  616 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  617 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  618 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  619 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  620 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  621 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  622 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  623 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  624 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  625 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  626 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  627 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  628 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  629 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  630 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  631 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  632 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  633 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  634 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  635 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  636 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  637 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  638 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  639 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  640 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  641 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  642 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  643 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  644 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  645 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  646 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  647 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  648 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  649 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  650 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  651 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  652 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  653 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  654 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  655 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  656 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  657 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  658 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  659 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  660 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  661 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  662 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  663 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  664 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  665 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  666 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  667 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  668 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  669 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  670 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  671 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  672 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  673 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  674 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  675 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  676 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  677 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  678 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  679 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  680 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  681 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  682 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  683 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  684 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  685 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  686 | best error P = 1062.523810 | best text = 'Wqen we have shuffled Jff this mortal coil'
# Generation  687 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  688 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  689 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  690 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  691 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  692 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  693 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  694 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  695 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  696 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  697 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  698 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  699 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  700 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  701 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  702 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  703 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  704 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  705 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  706 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  707 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  708 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  709 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  710 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  711 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  712 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  713 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  714 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  715 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  716 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  717 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  718 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  719 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  720 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  721 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  722 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  723 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  724 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  725 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  726 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  727 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  728 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  729 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  730 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  731 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  732 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  733 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  734 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  735 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  736 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  737 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  738 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  739 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  740 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  741 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  742 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  743 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  744 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  745 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  746 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  747 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  748 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  749 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  750 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  751 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  752 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  753 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  754 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  755 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  756 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  757 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  758 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  759 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  760 | best error P = 61.928571 | best text = 'Wqen we have shuffled off this mortal coil'
# Generation  761 | best error P = 0.000000 | best text = 'When we have shuffled off this mortal coil'
# Exact match found, stopping.

# %% [markdown]
# Now check the result by decrypting the ciphertext with the found plaintext.
# Assuming we have factored n to find p and q, and computed d.

# %%
# factoring n to find p and q
p, q = 149, 223          # 149 * 223 = 33227
phi = (p - 1) * (q - 1)
# find d, the modular inverse of e mod phi
def egcd(a, b):
    if b == 0:
        return (1, 0, a)
    x, y, g = egcd(b, a % b)
    return (y, x - (a // b) * y, g)

x, y, g = egcd(public_key, phi)
d = x % phi              # private exponent

#  decrypting the ciphertext
plaintext_chars = [chr(pow(c, d, n)) for c in ciphertext]
plaintext = "".join(plaintext_chars)
print(plaintext)
# Out:
# When we have shuffled off this mortal coil
