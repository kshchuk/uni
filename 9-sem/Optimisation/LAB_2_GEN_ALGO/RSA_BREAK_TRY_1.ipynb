# %% [markdown]
# Goal: Use a simple genetic algorithm (as in Holland’s and Goldberg’s “simple GA”) to approximate the unknown plaintext a such that
# rsa_lib.encrypt_text(candidate, public_key, n) is as close as possible (in mean squared error) to the given ciphertext b.

# %%
import random
from pathlib import Path

# Import your RSA library
from var import rsa_lib

# %%
# Directly from 8_encrypted_text.txt (variant 8)
ciphertext = [4012, 216, 1403, 10437, 8192, 15617, 1403, 8192, 216, 17270, 696, 1403, 8192, 12593, 216, 19224, 18807, 18807, 15951, 1403, 13821, 8192, 11101, 18807, 18807, 8192, 20733, 216, 7555, 12593, 8192, 31197, 11101, 692, 20733, 17270, 15951, 8192, 30299, 11101, 7555, 15951]

public_key = 65537
n = 28757

len(ciphertext), public_key, n
# Out:
# (42, 65537, 28757)

# %%
ALPHABET = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ, "
ALPHABET_SIZE = len(ALPHABET)
TEXT_LENGTH = 42  # must match the length of the unknown plaintext

# %%
def random_char():
    return random.choice(ALPHABET)

def random_text(length=TEXT_LENGTH):
    return "".join(random_char() for _ in range(length))

# %%
def encrypt_candidate(text):
    """
    Encrypt candidate plaintext using the given rsa_lib.
    Returns a list (or iterable) of integers.
    """
    return rsa_lib.encrypt_text(text, public_key, n)

# %% [markdown]
# Define the error \( P \) and fitness:
#
# $$
# P(x, b) = \frac{1}{n} \sum_{i=1}^n (b'_i - b_i)^2
# $$
#
# and convert this to a fitness to maximize, e.g.:
#
# $$
# \text{F}(x) = \frac{1}{1 + P(x, b)}
# $$

# %%
def error_P(candidate_text, target_cipher):
    cand_cipher = encrypt_candidate(candidate_text)

    # Safety: use min length if for some reason they differ
    L = min(len(cand_cipher), len(target_cipher))
    s = 0.0
    for i in range(L):
        diff = cand_cipher[i] - target_cipher[i]
        s += diff * diff
    return s / L

def fitness(candidate_text, target_cipher):
    P = error_P(candidate_text, target_cipher)
    return 1.0 / (1.0 + P)  # smaller error -> larger fitness

# %% [markdown]
# Initialize the population

# %%
POP_SIZE = 100

def initialize_population():
    return [random_text(TEXT_LENGTH) for _ in range(POP_SIZE)]

population = initialize_population()
len(population), population[0][:10]
# Out:
# (100, 'VzDmOtIPsQ')

# %% [markdown]
# Selection operator (tournament selection)

# %%
def tournament_select(population, fitnesses, tournament_size=3):
    """
    Return one selected individual from population using tournament selection.
    """
    selected_idx = random.randrange(len(population))
    for _ in range(tournament_size - 1):
        i = random.randrange(len(population))
        if fitnesses[i] > fitnesses[selected_idx]:
            selected_idx = i
    return population[selected_idx]

# %% [markdown]
# Crossover operator (one-point crossover on strings)

# %%
def one_point_crossover(parent1, parent2):
    assert len(parent1) == len(parent2)
    L = len(parent1)
    if L < 2:
        return parent1, parent2
    cut = random.randint(1, L - 1)  # cut point between 1 and L-1
    child1 = parent1[:cut] + parent2[cut:]
    child2 = parent2[:cut] + parent1[cut:]
    return child1, child2

# %% [markdown]
# Mutation operator ( with small probability per position, change a character to a random other character from the alphabet)

# %%
MUTATION_RATE = 0.02  # probability of mutating each character

def mutate(text):
    text_list = list(text)
    for i in range(len(text_list)):
        if random.random() < MUTATION_RATE:
            text_list[i] = random_char()
    return "".join(text_list)

# %% [markdown]
# One GA generation (with elitism)

# %%
CROSSOVER_RATE = 0.8
ELITE_COUNT = 2  # number of best individuals preserved each generation

# %%
def make_next_generation(population, target_cipher):
    # 1. Evaluate current population
    fitnesses = [fitness(ind, target_cipher) for ind in population]

    # 2. Sort by fitness (descending)
    pop_fit = list(zip(population, fitnesses))
    pop_fit.sort(key=lambda x: x[1], reverse=True)

    # 3. Elites
    new_population = [ind for ind, fit in pop_fit[:ELITE_COUNT]]

    # 4. Generate the rest via selection, crossover, mutation
    while len(new_population) < POP_SIZE:
        # Parent selection
        parent1 = tournament_select(population, fitnesses)
        parent2 = tournament_select(population, fitnesses)

        # Crossover
        if random.random() < CROSSOVER_RATE:
            child1, child2 = one_point_crossover(parent1, parent2)
        else:
            child1, child2 = parent1, parent2

        # Mutation
        child1 = mutate(child1)
        child2 = mutate(child2)

        new_population.append(child1)
        if len(new_population) < POP_SIZE:
            new_population.append(child2)

    # Also return current best individual for logging
    best_ind, best_fit = pop_fit[0]
    return new_population, best_ind, best_fit

# %%
MAX_GENERATIONS = 20000
TARGET_ERROR_THRESHOLD = 0.0  # stop if exact match is found

population = initialize_population()

for generation in range(MAX_GENERATIONS):
    # Evaluate and evolve
    population, best_ind, best_fit = make_next_generation(population, ciphertext)

    # Compute error explicitly for reporting
    best_error = error_P(best_ind, ciphertext)

    # REQUIRED OUTPUT: best current result for this iteration
    print(f"Generation {generation:4d} | best error P = {best_error:.6f} | best text = {repr(best_ind)}")

    # Stop if we hit perfect match (P = 0)
    if best_error <= TARGET_ERROR_THRESHOLD:
        print("Exact match found, stopping.")
        break
# Out:
# Generation    0 | best error P = 83203033.833333 | best text = 'qGXJlABHpivkEiB  ,JQiSFTWJFGcuBeJTcTASAStF'
# Generation    1 | best error P = 69175980.523810 | best text = 'qGXJlABHpivkEiB  UJvfQRNTfevkSmMZFxxewteIA'
# Generation    2 | best error P = 69175980.523810 | best text = 'qGXJlABHpivkEiB  UJvfQRNTfevkSmMZFxxewteIA'
# Generation    3 | best error P = 57577596.761905 | best text = 'eLXJlAzHplvkEiB  ,JQiSFTWJFGcpXWASX,eyYgJt'
# Generation    4 | best error P = 56408091.595238 | best text = 'qGXJlABHpivkEiB  cJvfrrpOGpEzpXWIHMAl CUHf'
# Generation    5 | best error P = 55391478.428571 | best text = 'qGXJlABHpivkEiB, UJvfyrpOGpElnvDQLPMkyhWdx'
# Generation    6 | best error P = 49485441.714286 | best text = 'vaXJlAzHplvkEiB  UJvfyrpOGpElnvDQLPMkyhWdx'
# Generation    7 | best error P = 44444142.357143 | best text = 'vaXJlAzHplvkEiB  UJvfyrpOGpElnvDQLPMkyUtdx'
# Generation    8 | best error P = 40757463.261905 | best text = 'vaXJlAzHplvkEiB  UJvfyrpOGpEzpXWIHX,pyYgJt'
# Generation    9 | best error P = 39241976.190476 | best text = 'vaXJlAzHplvkEiB  UJvfSFTWJFGzpXWIHX,pyYgJt'
# Generation   10 | best error P = 37830634.142857 | best text = 'qGXJlABHplvkEiB  UJvfSFTWJFGzpXWIHX,pyYgJt'
# Generation   11 | best error P = 34373358.523810 | best text = 'eLLJlABHplvkEiB tUJvfSFTWJFGzpXWIHX,pyYgJt'
# Generation   12 | best error P = 34373358.523810 | best text = 'eLLJlABHplvkEiB tUJvfSFTWJFGzpXWIHX,pyYgJt'
# Generation   13 | best error P = 31741432.023810 | best text = 'qGXJlABHplvkEOB  ,JQfyBpOGpElnvDlLPMkyYgJt'
# Generation   14 | best error P = 30563826.357143 | best text = 'eLLJldzHplvkEOB  IJQfyBpOGpElnvDlLPMkyYgJt'
# Generation   15 | best error P = 24158540.690476 | best text = 'eLLJkdBHLlvkEOB  ,JQfyBpOGpElnvDlLPMkyYgJt'
# Generation   16 | best error P = 24158540.690476 | best text = 'eLLJkdBHLlvkEOB  ,JQfyBpOGpElnvDlLPMkyYgJt'
# Generation   17 | best error P = 22603510.785714 | best text = 'eLLJkdBHLlvkEOB  IJQfyBpOGpElnvDlLPykyYgJt'
# Generation   18 | best error P = 20034305.309524 | best text = 'eLLJkdBHLlvkEOB  ,JQfysTWJFGzpvDlBMzjyYgJA'
# Generation   19 | best error P = 19867187.452381 | best text = 'eLLJkdBHLlvkEOB  ,JQfysTWJFGzpvDlBMzjyrgJt'
# Generation   20 | best error P = 19364713.047619 | best text = 'eLLJkdBHLlvkEOB  ,JQfysTPJFGzpXWIHMAlyrgJt'
# Generation   21 | best error P = 16786473.976190 | best text = 'eLLJkdBHLlvkEeB  ,,QfysTWJFGzpXWIHrAlyroJt'
# Generation   22 | best error P = 15898266.476190 | best text = 'eLLJlABHilvEEeB  ,,QfysTWJFGzpXWIHrAlyroJt'
# Generation   23 | best error P = 15898266.476190 | best text = 'eLLJlABHilvEEeB  ,,QfysTWJFGzpXWIHrAlyroJt'
# Generation   24 | best error P = 15604251.285714 | best text = 'aLLJlABHilvEEeB  ,,QfysTWJFGkpvWIHPflyroQt'
# Generation   25 | best error P = 15393937.928571 | best text = 'eLLgk BHLlskEOB  ,lQfJBTWJFGkpvWIQPykyrlJt'
# Generation   26 | best error P = 15141937.642857 | best text = 'eLLJkdBHilvEEEB  ,,QfysTWJFGzpXWIHrAlyroJt'
# Generation   27 | best error P = 14139210.142857 | best text = 'eLLJJdBHLlvEEeB  ,,QfysTFJFGzpvWIHPAlyroJt'
# Generation   28 | best error P = 14120160.404762 | best text = 'eLLJkdBHLlsGEOBr ,,QfysTWJFGzpXWIHrflyroJt'
# Generation   29 | best error P = 13803221.166667 | best text = 'eLLJkdBHLlsGEOBr ,,QfyoTWJFGzpXWIHrAlyYgJt'
# Generation   30 | best error P = 12482243.547619 | best text = 'eLLJkdBHLlsGEOB  ,,QfysTFsFGzpvWIHPAlyroJt'
# Generation   31 | best error P = 12482243.547619 | best text = 'eLLJkdBHLlsGEOB  ,,QfysTFsFGzpvWIHPAlyroJt'
# Generation   32 | best error P = 12180394.404762 | best text = 'eLLJkdBHLlsGEOB  UnvfysTuJFGzpvWIHPAlyroJt'
# Generation   33 | best error P = 11893484.642857 | best text = 'eLLJkdBHLlsGEOB  ,,QfybTFsFGzpvWIQfykyYgJt'
# Generation   34 | best error P = 11523910.571429 | best text = 'eLLJkdBHLlsGEOB  UnQfysTFeFGkpXWIHrAlyroJt'
# Generation   35 | best error P = 11238945.333333 | best text = 'eLLJkdBHLlsGEOB  ,,QfysTFJFGlnvWIQPAlyroJt'
# Generation   36 | best error P = 10133822.880952 | best text = 'eLLgk BHLlsGEOB  UnQVysTFeFGkpXWIHrAlyroJt'
# Generation   37 | best error P = 9350933.785714 | best text = 'eLLgk BHLlsGEOB  UnQVyoTFJFGlnvWIQfylyroJt'
# Generation   38 | best error P = 9099680.380952 | best text = 'eLLgk BHLlsGEOB  UnQVysTFJFGQnvWIQPAlyroJt'
# Generation   39 | best error P = 9034728.095238 | best text = 'eLLHkdBHLlsGEOB  UnQVysTFJFGQnvWIQPAlyroJt'
# Generation   40 | best error P = 8864984.000000 | best text = 'eLLXk BHLlsGEOB  UnQVysTFJFGQnvWIQPAlyroJt'
# Generation   41 | best error P = 8864984.000000 | best text = 'eLLXk BHLlsGEOB  UnQVysTFJFGQnvWIQPAlyroJt'
# Generation   42 | best error P = 8272749.047619 | best text = 'eLLgk BHLlsGERB  UnQVyoTFJFGlnvWIQPAOyroJt'
# Generation   43 | best error P = 8122475.047619 | best text = 'eLLgX BHLlsGERB  UnQVyoTFeFGQnvWIQPAlyroJt'
# Generation   44 | best error P = 8122475.047619 | best text = 'eLLgX BHLlsGERB  UnQVyoTFeFGQnvWIQPAlyroJt'
# Generation   45 | best error P = 8031561.214286 | best text = 'eLLgX BHLlsGERB  UnQVyoTFeFGlnvWIQPAOyrXJt'
# Generation   46 | best error P = 7620842.190476 | best text = 'eLLgk BHLlsGERB  UnQVyoTFJFGvnvWIQPAOyroJt'
# Generation   47 | best error P = 7620842.190476 | best text = 'eLLgk BHLlsGERB  UnQVyoTFJFGvnvWIQPAOyroJt'
# Generation   48 | best error P = 7422326.285714 | best text = 'eLLgk BHLlLGEOB  UnQVyoTFeFGQnvWIQPAOyroJt'
# Generation   49 | best error P = 7422326.285714 | best text = 'eLLgk BHLlLGEOB  UnQVyoTFeFGQnvWIQPAOyroJt'
# Generation   50 | best error P = 6687402.166667 | best text = 'eLLgk BHLlLGERB  AnQVyoTFeFGknvWILPAlyroJt'
# Generation   51 | best error P = 6687402.166667 | best text = 'eLLgk BHLlLGERB  AnQVyoTFeFGknvWILPAlyroJt'
# Generation   52 | best error P = 6460102.047619 | best text = 'eLLgk BHLlLGERB  AnQVyoTFeFGknvWILPAOyroJt'
# Generation   53 | best error P = 6460102.047619 | best text = 'eLLgk BHLlLGERB  AnQVyoTFeFGknvWILPAOyroJt'
# Generation   54 | best error P = 6393779.666667 | best text = 'eLLgk BHLlLGERB  AnQVEoTFeFGknvWILPAOyroJt'
# Generation   55 | best error P = 6100773.571429 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGQnvWIQPAOyroJt'
# Generation   56 | best error P = 6100773.571429 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGQnvWIQPAOyroJt'
# Generation   57 | best error P = 5490207.690476 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWILPAOyroJt'
# Generation   58 | best error P = 5490207.690476 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWILPAOyroJt'
# Generation   59 | best error P = 4696455.619048 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWILPAOyMoJt'
# Generation   60 | best error P = 4696455.619048 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWILPAOyMoJt'
# Generation   61 | best error P = 4696455.619048 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWILPAOyMoJt'
# Generation   62 | best error P = 4696455.619048 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWILPAOyMoJt'
# Generation   63 | best error P = 4538825.119048 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGvnvWIQuAOyMoJt'
# Generation   64 | best error P = 4516624.761905 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeFGv,vWILPAOyMoJt'
# Generation   65 | best error P = 4491717.785714 | best text = 'ZLLkk BHLmLGERB  AnQVyoTFeFGv,vWILPAOyMoJt'
# Generation   66 | best error P = 4370188.380952 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWILPAOyMoJt'
# Generation   67 | best error P = 4370188.380952 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWILPAOyMoJt'
# Generation   68 | best error P = 4370188.380952 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWILPAOyMoJt'
# Generation   69 | best error P = 4212557.880952 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWIQuAOyMoJt'
# Generation   70 | best error P = 4212557.880952 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWIQuAOyMoJt'
# Generation   71 | best error P = 4212557.880952 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWIQuAOyMoJt'
# Generation   72 | best error P = 4087872.142857 | best text = 'BLLkk BHLmLGbRB  AnQVyqTFeuGv,vWIQuAOyMoJt'
# Generation   73 | best error P = 4042437.309524 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWILTAOyMoJt'
# Generation   74 | best error P = 4042437.309524 | best text = 'eLLkk BHLmLGERB  AnQVyoTFeuGv,vWILTAOyMoJt'
# Generation   75 | best error P = 3740565.952381 | best text = 'eLLkk BHLmLGERB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   76 | best error P = 3740565.952381 | best text = 'eLLkk BHLmLGERB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   77 | best error P = 3711781.547619 | best text = 'eLLkX BHLmLGERB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   78 | best error P = 3600161.833333 | best text = 'BLLkk BHLmLGERB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   79 | best error P = 3600161.833333 | best text = 'BLLkk BHLmLGERB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   80 | best error P = 3455414.642857 | best text = 'BLLkk BHLmLGEzB  AnQVyoTCeuGvdgWILTAOyMoJt'
# Generation   81 | best error P = 3455414.642857 | best text = 'BLLkk BHLmLGEzB  AnQVyoTCeuGvdgWILTAOyMoJt'
# Generation   82 | best error P = 3455414.642857 | best text = 'BLLkk BHLmLGEzB  AnQVyoTCeuGvdgWILTAOyMoJt'
# Generation   83 | best error P = 3437588.857143 | best text = 'eLLkv BHLmLGEzB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   84 | best error P = 3437588.857143 | best text = 'eLLkv BHLmLGEzB  AnQVyoTCeuGv,vWILTAOyMoJt'
# Generation   85 | best error P = 3348354.523810 | best text = 'BLLks BHLmLGEzB  AnQVyoTCeuGvdgWILTAOyMoJt'
# Generation   86 | best error P = 3253157.309524 | best text = 'BLLks BHLmLGEzB  AnQVyoTmeuGv,vWILTAOyMoJt'
# Generation   87 | best error P = 3253157.309524 | best text = 'BLLks BHLmLGEzB  AnQVyoTmeuGv,vWILTAOyMoJt'
# Generation   88 | best error P = 3105526.547619 | best text = 'eLLkk BHLmLGERL  AnQVyoTCeuGvdgWyLTAOyMogt'
# Generation   89 | best error P = 3105526.547619 | best text = 'eLLkk BHLmLGERL  AnQVyoTCeuGvdgWyLTAOyMogt'
# Generation   90 | best error P = 2858062.309524 | best text = 'BLLks BHLmLGERL  AnQVyoTCeuGvdgWyLTAOyMogt'
# Generation   91 | best error P = 2721464.190476 | best text = 'BLLks BHLmLGEzL  AnQVyoTCeuGvdgWyLTAOyMogt'
# Generation   92 | best error P = 2721464.190476 | best text = 'BLLks BHLmLGEzL  AnQVyoTCeuGvdgWyLTAOyMogt'
# Generation   93 | best error P = 2708557.523810 | best text = 'BLLko BHLmLGEzL  AnQVyoTCeuGvdgWyLTAOyMogt'
# Generation   94 | best error P = 2654775.166667 | best text = 'sLLkv BHLmLGERL  A QVyoTueuGvdgWyLTAOyMogt'
# Generation   95 | best error P = 2581705.833333 | best text = 'sLLkv BHLmLGEXL  A QVyoTueuGvdgWyLTAOyMogt'
# Generation   96 | best error P = 2581705.833333 | best text = 'sLLkv BHLmLGEXL  A QVyoTueuGvdgWyLTAOyMogt'
# Generation   97 | best error P = 2472255.738095 | best text = 'BLLks BHLmLGEzL  AnQVyoTueuGvdgWyLTAOyMogt'
# Generation   98 | best error P = 2470977.380952 | best text = 'BLLks BHLmLGyzL SAnQVyoTueuGvdgWyLTAOyMogt'
# Generation   99 | best error P = 2462988.523810 | best text = 'BLLks BHLmLGEzL  AnQVyoTueuGvIgWyLTAOyMogt'
# Generation  100 | best error P = 2462988.523810 | best text = 'BLLks BHLmLGEzL  AnQVyoTueuGvIgWyLTAOyMogt'
# Generation  101 | best error P = 2376232.976190 | best text = 'BLLks BHLmLGEzL  A QVyoTueuGvdgWyLTAObMogt'
# Generation  102 | best error P = 2308085.952381 | best text = 'BLLkv BHLmLGyzL SAnQVyoTueuGvdgWyLTuOyMogt'
# Generation  103 | best error P = 2308085.952381 | best text = 'BLLkv BHLmLGyzL SAnQVyoTueuGvdgWyLTuOyMogt'
# Generation  104 | best error P = 2308085.952381 | best text = 'BLLkv BHLmLGyzL SAnQVyoTueuGvdgWyLTuOyMogt'
# Generation  105 | best error P = 2301082.428571 | best text = 'BLLks BHLmLGEzL SAnQVyoTueuGvdgWyLTuOyMogt'
# Generation  106 | best error P = 2116453.357143 | best text = 'BLLkv BHLmLGyzLuSAnQVyoTueuGvdgWyLTuOyMogt'
# Generation  107 | best error P = 2044048.047619 | best text = 'BLLkv BHLmLGyzLuSAnQVyoTueuGvdgWyLTuOyMogS'
# Generation  108 | best error P = 2044048.047619 | best text = 'BLLkv BHLmLGyzLuSAnQVyoTueuGvdgWyLTuOyMogS'
# Generation  109 | best error P = 2044048.047619 | best text = 'BLLkv BHLmLGyzLuSAnQVyoTueuGvdgWyLTuOyMogS'
# Generation  110 | best error P = 1977725.666667 | best text = 'BLLkv BHLmLGEzLuSAnQVyoTueuGvdgWyLTuOyMogS'
# Generation  111 | best error P = 1975240.357143 | best text = 'BLLkE BHLmLGEzLuSAnQVyoTueuGvIgWyLTu yMogS'
# Generation  112 | best error P = 1918591.857143 | best text = 'BLLkv aHLmLGyzLuSAnQVyoTueuGvlgWyLTuOyMogt'
# Generation  113 | best error P = 1918591.857143 | best text = 'BLLkv aHLmLGyzLuSAnQVyoTueuGvlgWyLTuOyMogt'
# Generation  114 | best error P = 1860530.976190 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvdgWyLTuOyMogt'
# Generation  115 | best error P = 1788125.666667 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvdgWyLTuOyMogS'
# Generation  116 | best error P = 1776406.976190 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueCGvdgWyLTuOyMogS'
# Generation  117 | best error P = 1776406.976190 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueCGvdgWyLTuOyMogS'
# Generation  118 | best error P = 1768041.095238 | best text = 'BLLkv aHLmLGEzLuSAnQqyoTueuGvdgWyLTuOyMogS'
# Generation  119 | best error P = 1713737.095238 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTueuGvdgWyLTuOyMogS'
# Generation  120 | best error P = 1696886.238095 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvdgWyLTS yMogS'
# Generation  121 | best error P = 1682664.166667 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvlgWyLTuOHMogS'
# Generation  122 | best error P = 1682664.166667 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvlgWyLTuOHMogS'
# Generation  123 | best error P = 1682664.166667 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvlgWyLTuOHMogS'
# Generation  124 | best error P = 1682664.166667 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvlgWyLTuOHMogS'
# Generation  125 | best error P = 1682664.166667 | best text = 'BLLkv aHLmLGEzLuSAnQVyoTueuGvlgWyLTuOHMogS'
# Generation  126 | best error P = 1616139.238095 | best text = 'BLLkg aHLmLGEzLuSAnQVvoTueuGvIgWyLT OyMogS'
# Generation  127 | best error P = 1607269.880952 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTueuGvIgWyLTuOHMogS'
# Generation  128 | best error P = 1556408.738095 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTubuGvlgWyLTuOHMogS'
# Generation  129 | best error P = 1552907.309524 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTubuGvlgWyLTnOHMogS'
# Generation  130 | best error P = 1552907.309524 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTubuGvlgWyLTnOHMogS'
# Generation  131 | best error P = 1534926.380952 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTueuGvIgWyLT OHMogS'
# Generation  132 | best error P = 1534926.380952 | best text = 'BLLkv aHLmLGEzLuSAnQVvoTueuGvIgWyLT OHMogS'
# Generation  133 | best error P = 1468078.095238 | best text = 'BLLkg aHLmLGEzLuSAnQVvoTubuGvlgWyLT OHMogS'
# Generation  134 | best error P = 1468078.095238 | best text = 'BLLkg aHLmLGEzLuSAnQVvoTubuGvlgWyLT OHMogS'
# Generation  135 | best error P = 1423807.142857 | best text = 'BLLkv aHLmLGEzLuSAnQVvofueuGvIgWyLT OHMogS'
# Generation  136 | best error P = 1423807.142857 | best text = 'BLLkv aHLmLGEzLuSAnQVvofueuGvIgWyLT OHMogS'
# Generation  137 | best error P = 1423807.142857 | best text = 'BLLkv aHLmLGEzLuSAnQVvofueuGvIgWyLT OHMogS'
# Generation  138 | best error P = 1407820.000000 | best text = 'BLLkg aHLmLGEzLuSAnQVvofueuGvIgWyLT OHMogS'
# Generation  139 | best error P = 1407820.000000 | best text = 'BLLkg aHLmLGEzLuSAnQVvofueuGvIgWyLT OHMogS'
# Generation  140 | best error P = 1386398.761905 | best text = 'BLLkv aHLmLGEzLuSunQVvofueuGvIgWyLT OHMogS'
# Generation  141 | best error P = 1371417.333333 | best text = 'BLLkg aHLmLGEzLuSunQVvofueuGvlgWyLT OHMogS'
# Generation  142 | best error P = 1371417.333333 | best text = 'BLLkg aHLmLGEzLuSunQVvofueuGvlgWyLT OHMogS'
# Generation  143 | best error P = 1340122.857143 | best text = 'BLLkg aHLmLGEzLuuAnQVvofueuGvIgWyLT OHMogS'
# Generation  144 | best error P = 1340122.857143 | best text = 'BLLkg aHLmLGEzLuuAnQVvofueuGvIgWyLT OHMogS'
# Generation  145 | best error P = 1340122.857143 | best text = 'BLLkg aHLmLGEzLuuAnQVvofueuGvIgWyLT OHMogS'
# Generation  146 | best error P = 1322070.857143 | best text = 'BLLkg aHLmLGgzLuSunQVvofueuGvIgWyLT nHMogm'
# Generation  147 | best error P = 1322070.857143 | best text = 'BLLkg aHLmLGgzLuSunQVvofueuGvIgWyLT nHMogm'
# Generation  148 | best error P = 1322070.857143 | best text = 'BLLkg aHLmLGgzLuSunQVvofueuGvIgWyLT nHMogm'
# Generation  149 | best error P = 1315430.666667 | best text = 'BLLkg aHLmLGgzLuSunQVvofuejGvIgWyLT OHMogS'
# Generation  150 | best error P = 1315430.666667 | best text = 'BLLkg aHLmLGgzLuSunQVvofuejGvIgWyLT OHMogS'
# Generation  151 | best error P = 1315430.666667 | best text = 'BLLkg aHLmLGgzLuSunQVvofuejGvIgWyLT OHMogS'
# Generation  152 | best error P = 1288467.690476 | best text = 'BLLkg aHLmLGgzLuSunQVvofuejGvIgWyLT OHMogm'
# Generation  153 | best error P = 1278427.047619 | best text = 'BLLkg aHLmLGEzLuuunQVvofueuGvIgWyLT nHMogm'
# Generation  154 | best error P = 1278427.047619 | best text = 'BLLkg aHLmLGEzLuuunQVvofueuGvIgWyLT nHMogm'
# Generation  155 | best error P = 1278427.047619 | best text = 'BLLkg aHLmLGEzLuuunQVvofueuGvIgWyLT nHMogm'
# Generation  156 | best error P = 1271786.857143 | best text = 'BLLkg aHLmLGEzLuuunQVvofuejGvIgWyLT OHMogS'
# Generation  157 | best error P = 1268400.452381 | best text = 'BLLkg aHLmLGgzLuSunQVvpfuejGvIgWyLT OHMXgS'
# Generation  158 | best error P = 1264025.047619 | best text = 'BLLkv aHLOLGgzLuuunQVvofueuGvIgWyLT nHMogm'
# Generation  159 | best error P = 1250396.571429 | best text = 'BLLkg aHL LGgzLuuunQVvofueuGvIgWyLT nHMogm'
# Generation  160 | best error P = 1234310.904762 | best text = 'BLLkg aHL LGgzLuSunQVvofugjGvIgWyLT OHMogm'
# Generation  161 | best error P = 1234310.904762 | best text = 'BLLkg aHL LGgzLuSunQVvofugjGvIgWyLT OHMogm'
# Generation  162 | best error P = 1192305.095238 | best text = 'BLLkg aHLOLGgzLuuunQVvpfuejGvIgWyLT OHMogm'
# Generation  163 | best error P = 1192305.095238 | best text = 'BLLkg aHLOLGgzLuuunQVvpfuejGvIgWyLT OHMogm'
# Generation  164 | best error P = 1192305.095238 | best text = 'BLLkg aHLOLGgzLuuunQVvpfuejGvIgWyLT OHMogm'
# Generation  165 | best error P = 1158112.595238 | best text = 'BLLkg aHLOLGgzLuuunQVvpfuvjGvIgWyLT OHMogm'
# Generation  166 | best error P = 1134758.595238 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMogm'
# Generation  167 | best error P = 1134758.595238 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMogm'
# Generation  168 | best error P = 1134758.595238 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMogm'
# Generation  169 | best error P = 1133212.023810 | best text = 'BLLkg aHLOLGgzLuuunQVvpfuvjGvIgWyLT OHMXgm'
# Generation  170 | best error P = 1133212.023810 | best text = 'BLLkg aHLOLGgzLuuunQVvpfuvjGvIgWyLT OHMXgm'
# Generation  171 | best error P = 1109858.023810 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMXgm'
# Generation  172 | best error P = 1109858.023810 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMXgm'
# Generation  173 | best error P = 1109858.023810 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMXgm'
# Generation  174 | best error P = 1109858.023810 | best text = 'BLLkg GHLOLGgzLuuunQVvpfugjGvIgWyLT OHMXgm'
# Generation  175 | best error P = 1108170.809524 | best text = 'BLLkg GHLOLGbzLuuunQVvpfugjGvIgWyLT OHMXgm'
# Generation  176 | best error P = 1080576.309524 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  177 | best error P = 1080576.309524 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  178 | best error P = 1073209.452381 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  179 | best error P = 1073209.452381 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  180 | best error P = 1073209.452381 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  181 | best error P = 1073209.452381 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  182 | best error P = 1073209.452381 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  183 | best error P = 1073209.452381 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgWyLT OHMXgm'
# Generation  184 | best error P = 1053962.380952 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugTGvIgWyLT OHMXgm'
# Generation  185 | best error P = 925336.428571 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjGvIgMyLT OHMXgm'
# Generation  186 | best error P = 925336.428571 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjGvIgMyLT OHMXgm'
# Generation  187 | best error P = 925336.428571 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjGvIgMyLT OHMXgm'
# Generation  188 | best error P = 917969.571429 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgMyLT OHMXgm'
# Generation  189 | best error P = 917969.571429 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjGvIgMyLT OHMXgm'
# Generation  190 | best error P = 901250.523810 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjGvIgMyLT OHMkgm'
# Generation  191 | best error P = 901250.523810 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjGvIgMyLT OHMkgm'
# Generation  192 | best error P = 901250.523810 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjGvIgMyLT OHMkgm'
# Generation  193 | best error P = 832475.404762 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjivIgMyLT OHMXgm'
# Generation  194 | best error P = 831477.190476 | best text = 'BLLkg aHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  195 | best error P = 824110.333333 | best text = 'BLLkg GHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  196 | best error P = 808389.500000 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  197 | best error P = 808389.500000 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  198 | best error P = 808389.500000 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  199 | best error P = 808389.500000 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  200 | best error P = 808389.500000 | best text = 'BLGkg GHLOLGgzLuuunaVvpfugjivIgMyLT OHMkgm'
# Generation  201 | best error P = 790715.142857 | best text = 'BLGkg GHLOLGgzLuuunaVbpfugjivIgMyLT OHMkgm'
# Generation  202 | best error P = 783274.261905 | best text = 'BLGkg aHLOLGHzLuuuRadvpfugjivIgMyLT OHMkgm'
# Generation  203 | best error P = 783274.261905 | best text = 'BLGkg aHLOLGHzLuuuRadvpfugjivIgMyLT OHMkgm'
# Generation  204 | best error P = 783274.261905 | best text = 'BLGkg aHLOLGHzLuuuRadvpfugjivIgMyLT OHMkgm'
# Generation  205 | best error P = 775907.404762 | best text = 'BLGkg GHLOLGHzLuuuRadvpfugjivIgMyLT OHMkgm'
# Generation  206 | best error P = 771109.023810 | best text = 'BLGkg GHLOLGgzLuuunadvpfugjivIgMyLT OHMkgm'
# Generation  207 | best error P = 771109.023810 | best text = 'BLGkg GHLOLGgzLuuunadvpfugjivIgMyLT OHMkgm'
# Generation  208 | best error P = 763437.619048 | best text = 'BLGkgnGHLOLGHzLuuuRadvpfugjivIgMyLT OHMkgm'
# Generation  209 | best error P = 763437.619048 | best text = 'BLGkgnGHLOLGHzLuuuRadvpfugjivIgMyLT OHMkgm'
# Generation  210 | best error P = 761028.000000 | best text = 'BLGpgnGHLOLGHzLuuunadvpfuHjivIgMyLT OHMkgm'
# Generation  211 | best error P = 744990.666667 | best text = 'BLGkgnGHLOLGHzLuuunadvpfuHjivIgMyLT OHMkgm'
# Generation  212 | best error P = 744990.666667 | best text = 'BLGkgnGHLOLGHzLuuunadvpfuHjivIgMyLT OHMkgm'
# Generation  213 | best error P = 744990.666667 | best text = 'BLGkgnGHLOLGHzLuuunadvpfuHjivIgMyLT OHMkgm'
# Generation  214 | best error P = 744990.666667 | best text = 'BLGkgnGHLOLGHzLuuunadvpfuHjivIgMyLT OHMkgm'
# Generation  215 | best error P = 743386.261905 | best text = 'BLGkgnGHLSLGgzLuuunadvpfugjivIgMyLT OHMkgm'
# Generation  216 | best error P = 728497.047619 | best text = 'BLGkgnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  217 | best error P = 728497.047619 | best text = 'BLGkgnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  218 | best error P = 728497.047619 | best text = 'BLGkgnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  219 | best error P = 728497.047619 | best text = 'BLGkgnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  220 | best error P = 726809.833333 | best text = 'BLGkbnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  221 | best error P = 726809.833333 | best text = 'BLGkbnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  222 | best error P = 726809.833333 | best text = 'BLGkbnGHLSLGgzLuuunadvpuugjivIgMyLT OHMkgm'
# Generation  223 | best error P = 721174.285714 | best text = 'BLGkbnGHLSLGgzLuuumadvpuugjivIgMyLT OHMkgm'
# Generation  224 | best error P = 721174.285714 | best text = 'BLGkbnGHLSLGgzLuuumadvpuugjivIgMyLT OHMkgm'
# Generation  225 | best error P = 721174.285714 | best text = 'BLGkbnGHLSLGgzLuuumadvpuugjivIgMyLT OHMkgm'
# Generation  226 | best error P = 709135.476190 | best text = 'BLGkbnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  227 | best error P = 709135.476190 | best text = 'BLGkbnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  228 | best error P = 709135.476190 | best text = 'BLGkbnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  229 | best error P = 709135.476190 | best text = 'BLGkbnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  230 | best error P = 703998.404762 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  231 | best error P = 703998.404762 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  232 | best error P = 703998.404762 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugjivIgMyLT OHMkgm'
# Generation  233 | best error P = 702358.190476 | best text = 'BLGkb GHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  234 | best error P = 702358.190476 | best text = 'BLGkb GHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  235 | best error P = 689888.404762 | best text = 'BLGkbnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  236 | best error P = 684751.333333 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  237 | best error P = 684751.333333 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  238 | best error P = 684751.333333 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  239 | best error P = 684751.333333 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  240 | best error P = 684751.333333 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  241 | best error P = 684751.333333 | best text = 'BLGkHnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  242 | best error P = 679252.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  243 | best error P = 679252.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT OHMkgm'
# Generation  244 | best error P = 676292.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkgm'
# Generation  245 | best error P = 676292.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkgm'
# Generation  246 | best error P = 676292.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkgm'
# Generation  247 | best error P = 676292.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkgm'
# Generation  248 | best error P = 676292.523810 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkgm'
# Generation  249 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  250 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  251 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  252 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  253 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  254 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  255 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  256 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  257 | best error P = 675788.309524 | best text = 'BLGybnGHLSLGgzLuuunadbpuugTivIgMyLT mHMkbm'
# Generation  258 | best error P = 671381.452381 | best text = 'BLGybnGHLSLGgzLuuunGdbpuugTivIgMyLT OHMkbm'
# Generation  259 | best error P = 669152.142857 | best text = 'BiGybnGHLSLGgzLuuunGdbpuugTivIgMyLT mHMkgm'
# Generation  260 | best error P = 668421.452381 | best text = 'BLGybnGHLSLGgzLuuunGdbpuugTivIgMyLT mHMkbm'
# Generation  261 | best error P = 668421.452381 | best text = 'BLGybnGHLSLGgzLuuunGdbpuugTivIgMyLT mHMkbm'
# Generation  262 | best error P = 666250.119048 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMyLT OHMkgm'
# Generation  263 | best error P = 666250.119048 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMyLT OHMkgm'
# Generation  264 | best error P = 663290.119048 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMyLT mHMkgm'
# Generation  265 | best error P = 663290.119048 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMyLT mHMkgm'
# Generation  266 | best error P = 662785.904762 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMyLT mHMkbm'
# Generation  267 | best error P = 662785.904762 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMyLT mHMkbm'
# Generation  268 | best error P = 651551.119048 | best text = 'BLGygnGHLSLGgzLuuumGdbpuugTivIgMkLT mHMkgm'
# Generation  269 | best error P = 649863.904762 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMkLT mHMkgm'
# Generation  270 | best error P = 649863.904762 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMkLT mHMkgm'
# Generation  271 | best error P = 649863.904762 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMkLT mHMkgm'
# Generation  272 | best error P = 649359.690476 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMkLT mHMkbm'
# Generation  273 | best error P = 649359.690476 | best text = 'BLGybnGHLSLGgzLuuumGdbpuugTivIgMkLT mHMkbm'
# Generation  274 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  275 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  276 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  277 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  278 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  279 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  280 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  281 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  282 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  283 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  284 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  285 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  286 | best error P = 645590.547619 | best text = 'BLGybnGHLSLGgzLuuumGdbkuugTivIgMkLT mHMkbm'
# Generation  287 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  288 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  289 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  290 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  291 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  292 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  293 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  294 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  295 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  296 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  297 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  298 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  299 | best error P = 637213.119048 | best text = 'BLGybnGHLSLGgzLuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  300 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  301 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  302 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  303 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  304 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  305 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  306 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  307 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  308 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  309 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  310 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  311 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  312 | best error P = 632417.904762 | best text = 'BLGybnGHLSLGgILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  313 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  314 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  315 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  316 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  317 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  318 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  319 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  320 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  321 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  322 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  323 | best error P = 625593.619048 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIgMkLT mHMkbm'
# Generation  324 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  325 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  326 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  327 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  328 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  329 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  330 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  331 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  332 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  333 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  334 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  335 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  336 | best error P = 618769.333333 | best text = 'BLGybnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  337 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  338 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  339 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  340 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  341 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  342 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  343 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  344 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  345 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  346 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  347 | best error P = 613632.261905 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLT mHMkbm'
# Generation  348 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  349 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  350 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  351 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  352 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  353 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  354 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  355 | best error P = 611273.595238 | best text = 'BLGyHnGHLSLGHILuuumGtbkuugTivIHMkLTOmHMkbm'
# Generation  356 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  357 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  358 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  359 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  360 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  361 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  362 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  363 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  364 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  365 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  366 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  367 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  368 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  369 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  370 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  371 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  372 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  373 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  374 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  375 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  376 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  377 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  378 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  379 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  380 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  381 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  382 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  383 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  384 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  385 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  386 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  387 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  388 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  389 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  390 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  391 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  392 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  393 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  394 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  395 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  396 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  397 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  398 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  399 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  400 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  401 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  402 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  403 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  404 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  405 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  406 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  407 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  408 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  409 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  410 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  411 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  412 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  413 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  414 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  415 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  416 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  417 | best error P = 606136.523810 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTivIHMkLTOmHMkbm'
# Generation  418 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  419 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  420 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  421 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  422 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  423 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  424 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  425 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  426 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  427 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  428 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  429 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  430 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  431 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  432 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  433 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  434 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  435 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  436 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  437 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  438 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  439 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  440 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  441 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  442 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  443 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  444 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  445 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  446 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  447 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  448 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# Generation  449 | best error P = 599048.500000 | best text = 'BLGyHnGHLSLGHILuuumGtHkuugTibIHMkLTOmHMkbm'
# ...
# Generation 5668 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5669 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5670 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5671 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5672 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5673 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5674 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5675 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5676 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5677 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5678 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5679 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5680 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5681 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5682 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5683 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5684 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5685 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5686 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5687 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5688 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5689 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5690 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5691 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5692 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5693 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5694 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5695 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5696 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5697 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5698 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5699 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5700 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5701 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5702 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5703 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5704 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5705 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5706 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5707 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5708 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5709 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5710 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5711 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5712 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5713 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5714 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5715 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5716 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5717 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5718 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5719 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5720 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5721 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5722 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5723 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5724 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5725 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5726 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5727 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5728 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5729 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5730 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5731 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5732 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5733 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5734 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5735 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5736 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5737 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5738 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5739 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5740 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5741 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5742 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5743 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5744 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5745 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5746 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5747 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5748 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5749 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5750 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5751 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5752 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5753 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5754 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5755 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5756 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5757 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5758 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5759 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5760 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5761 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5762 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5763 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5764 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5765 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5766 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5767 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5768 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5769 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5770 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5771 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5772 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5773 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5774 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5775 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5776 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5777 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5778 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5779 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5780 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5781 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5782 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5783 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5784 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5785 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5786 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5787 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5788 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5789 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5790 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5791 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5792 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5793 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5794 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5795 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5796 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5797 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5798 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5799 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5800 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5801 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5802 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5803 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5804 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5805 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5806 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5807 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5808 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5809 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5810 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5811 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5812 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5813 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5814 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5815 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5816 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'
# Generation 5817 | best error P = 576744.761905 | best text = 'BLGyHnGHLSLGHILuuumGtHkuuHTLbIHMkLTSmHMkbm'

# %% [markdown]
# Now check the result by decrypting the ciphertext with the found plaintext.
# Assuming we have factored n to find p and q, and computed d.

# %%
# factoring n to find p and q
p, q = 149, 223          # 149 * 223 = 33227
phi = (p - 1) * (q - 1)
# find d, the modular inverse of e mod phi
def egcd(a, b):
    if b == 0:
        return (1, 0, a)
    x, y, g = egcd(b, a % b)
    return (y, x - (a // b) * y, g)

x, y, g = egcd(public_key, phi)
d = x % phi              # private exponent

#  decrypting the ciphertext
plaintext_chars = [chr(pow(c, d, n)) for c in ciphertext]
plaintext = "".join(plaintext_chars)
print(plaintext)
# Out:
# T㳰摽捦ܜm摽঻ʹ䍢ܜƍ摽l摽m攚捦䮎ܜᶉ啠ܜ䍢ᶉܜlᶉ沰㱚ܜl攚啠ʹ
